# %% [markdown]
# <a href="https://colab.research.google.com/github/camilouribeg/DS4I-Project/blob/main/04_association_rules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data mining

# %% [markdown]
# ## EXERCISE: Association analysis from scratch

# %% [markdown]
# ### Generate frequent itemsets
#
# Let's find all sets of items with a support greater than some threshold.
#
# We define 4 functions for generating frequent itemsets:
# * createC1 - Create first candidate itemsets for k=1
# * scanD - Identify itemsets that meet the support threshold
# * aprioriGen - Generate the next list of candidates
# * apriori - Generate all frequent itemsets
#
# See slides for explanation of functions.

# %%
def createC1(dataset):
    "Create a list of candidate item sets of size one."
    c1 = []
    for transaction in dataset:
        for item in transaction:
            if not [item] in c1:
                c1.append([item])
    c1.sort()
    #frozenset because it will be a ket of a dictionary.
    return list(map(frozenset, c1))



def scanD(dataset, candidates, min_support):
    "Returns all candidates that meets a minimum support level"
    sscnt = {}
    for tid in dataset:
        for can in candidates:
            if can.issubset(tid):
                sscnt.setdefault(can, 0)
                sscnt[can] += 1

    num_items = float(len(dataset))
    retlist = []
    support_data = {}
    for key in sscnt:
        support = sscnt[key] / num_items
        if support >= min_support:
            retlist.insert(0, key)
            support_data[key] = support
    return retlist, support_data


def aprioriGen(freq_sets, k):
    "Generate the joint transactions from candidate sets"
    retList = []
    lenLk = len(freq_sets)
    for i in range(lenLk):
        for j in range(i + 1, lenLk):
            L1 = list(freq_sets[i])[:k - 2]
            L2 = list(freq_sets[j])[:k - 2]
            L1.sort()
            L2.sort()
            if L1 == L2:
                retList.append(freq_sets[i] | freq_sets[j]) # | is set union
    return retList


def apriori(dataset, min_support=0.5):
    "Generate a list of candidate item sets"
    C1 = createC1(dataset)
    D = list(map(set, dataset))
    L1, support_data = scanD(D, C1, min_support)
    L = [L1]
    k = 2
    while (len(L[k - 2]) > 0):
        Ck = aprioriGen(L[k - 2], k)
        Lk, supK = scanD(D, Ck, min_support)
        support_data.update(supK)
        L.append(Lk)
        k += 1

    return L, support_data
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Itemset generation on sample data

# %%
MIN_SUPPORT= 0.5

# Sample data
DATASET = [['Mango', 'Onion', 'Apple'], ['Corn', 'Onion', 'Eggs'], ['Mango', 'Corn', 'Onion', 'Eggs'], ['Mango', 'Eggs']]
DATASET = [['A', 'C', 'D'], ['B', 'C', 'E'], ['A', 'B', 'C','E'],['B', 'E']]
print('Dataset in list-of-lists format:\n', DATASET, '\n')

# Generate a first candidate itemsets for k=1
C1 = createC1(DATASET)
print('Initial 1-itemset candidates:\n', C1, '\n')

# Convert data to a list of sets
D = list(map(set, DATASET))
print('Dataset in list-of-sets format:\n', D, '\n')

# Identify items that meet support threshold (0.5)
# Note that {4} isn't here as it only occurs in one transaction.
# Remove it so we don't generate any further candidate itemsets containing {4}.
L1, support_data = scanD(D, C1, MIN_SUPPORT)
print('1-itemsets that appear in at least 50% of transactions:\n', L1, '\n')

# Generate the next list of candidates
print('Next set of candidates:\n', aprioriGen(L1,2), '\n')

# Generate all candidate itemsets
L, support_data = apriori(DATASET, min_support=MIN_SUPPORT)
print('Full list of candidate itemsets:\n', L, '\n')
print('Support values for candidate itemsets:\n', support_data, '\n')
# Out:
# Dataset in list-of-lists format:
#  [['A', 'C', 'D'], ['B', 'C', 'E'], ['A', 'B', 'C', 'E'], ['B', 'E']]
#
# Initial 1-itemset candidates:
#  [frozenset({'A'}), frozenset({'B'}), frozenset({'C'}), frozenset({'D'}), frozenset({'E'})]
#
# Dataset in list-of-sets format:
#  [{'C', 'D', 'A'}, {'E', 'C', 'B'}, {'E', 'C', 'B', 'A'}, {'E', 'B'}]
#
# 1-itemsets that appear in at least 50% of transactions:
#  [frozenset({'E'}), frozenset({'B'}), frozenset({'C'}), frozenset({'A'})]
#
# Next set of candidates:
#  [frozenset({'B', 'E'}), frozenset({'C', 'E'}), frozenset({'E', 'A'}), frozenset({'C', 'B'}), frozenset({'B', 'A'}), frozenset({'C', 'A'})]
#
# Full list of candidate itemsets:
#  [[frozenset({'E'}), frozenset({'B'}), frozenset({'C'}), frozenset({'A'})], [frozenset({'C', 'B'}), frozenset({'C', 'E'}), frozenset({'B', 'E'}), frozenset({'C', 'A'})], [frozenset({'E', 'C', 'B'})], []]
#
# Support values for candidate itemsets:
#  {frozenset({'A'}): 0.5, frozenset({'C'}): 0.75, frozenset({'B'}): 0.75, frozenset({'E'}): 0.75, frozenset({'C', 'A'}): 0.5, frozenset({'B', 'E'}): 0.75, frozenset({'C', 'E'}): 0.5, frozenset({'C', 'B'}): 0.5, frozenset({'E', 'C', 'B'}): 0.5}
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### TODO Exploring support thresholds
#
# * Generate frequent itemsets with a support threshold of 0.7
# * How many frequent itemsets do we get at 0.7?
# >> 4
# * How many do we get at 0.3?
# >>9
# * Do you have datasets that resemble transactions?
# >> Movies, Grocery, Medicare
# * What about the apps/websites you use?
# >> Netflix, Amazon, other recommender systems

# %%
# TODO: replace the content of this cell with your Python solution
L, support_data = apriori(DATASET, min_support = 0.7)
print('Full list of candidate itemsets:\n', L, '\n')
print('Support values for candidate itemsets:\n', support_data,'\n')
print()
L, support_data = apriori(DATASET, min_support = 0.3)
print('Full list of candidate itemsets:\n', L, '\n')
print('Support values for candidate itemsets:\n', support_data,'\n')
# Out:
# Full list of candidate itemsets:
#  [[frozenset({'E'}), frozenset({'B'}), frozenset({'C'})], [frozenset({'B', 'E'})], []]
#
# Support values for candidate itemsets:
#  {frozenset({'C'}): 0.75, frozenset({'B'}): 0.75, frozenset({'E'}): 0.75, frozenset({'B', 'E'}): 0.75}
#
#
# Full list of candidate itemsets:
#  [[frozenset({'E'}), frozenset({'B'}), frozenset({'C'}), frozenset({'A'})], [frozenset({'C', 'B'}), frozenset({'C', 'E'}), frozenset({'B', 'E'}), frozenset({'C', 'A'})], [frozenset({'E', 'C', 'B'})], []]
#
# Support values for candidate itemsets:
#  {frozenset({'A'}): 0.5, frozenset({'C'}): 0.75, frozenset({'B'}): 0.75, frozenset({'E'}): 0.75, frozenset({'C', 'A'}): 0.5, frozenset({'B', 'E'}): 0.75, frozenset({'C', 'E'}): 0.5, frozenset({'C', 'B'}): 0.5, frozenset({'E', 'C', 'B'}): 0.5}
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## *STOP PLEASE. THE FOLLOWING IS FOR THE NEXT EXERCISE. THANKS.*

# %% [markdown]
# ## EXERCISE:  Mine association rules
#
# Given frequent itemsets, we can create association rules.
#
# We add three more functions:
# * calc_confidence - Identify rules that meet the confidence threshold
# * rules_from_conseq - Recursively generate and evaluate candidate rules
# * generateRules - Mine all confident association rules
#
# See slides for explanation of functions.

# %%
def calc_confidence(freqSet, H, support_data, rules, min_confidence=0.7):
    "Evaluate the rule generated"
    pruned_H = []
    for conseq in H:
        conf = support_data[freqSet] / support_data[freqSet - conseq]
        if conf >= min_confidence:
            #print(freqSet - conseq, '--->', conseq, 'conf:', conf)
            rules.append((freqSet - conseq, conseq, conf))
            pruned_H.append(conseq)
    return pruned_H


def rules_from_conseq(freqSet, H, support_data, rules, min_confidence=0.7):
    "Generate a set of candidate rules"
    m = len(H[0])
    Hmp1 = createC1(H)
    Hmp1 = calc_confidence(freqSet, Hmp1,  support_data, rules, min_confidence)
    if len(Hmp1) <= len(freqSet):
        if (len(freqSet) > (m + 1)):
            Hmp1 = aprioriGen(H, m + 1)
            Hmp1 = calc_confidence(freqSet, Hmp1,  support_data, rules, min_confidence)
            if len(Hmp1) > 1:
                rules_from_conseq(freqSet, Hmp1, support_data, rules, min_confidence)

def generateRules(L, support_data, min_confidence=0.7):
    """Create the association rules
    L: list of frequent item sets
    support_data: support data for those itemsets
    min_confidence: minimum confidence threshold
    """
    rules = []
    for i in range(1, len(L)):
        for freqSet in L[i]:
            H1 = [frozenset([item]) for item in freqSet]
            if (i > 1):
                rules_from_conseq(freqSet, H1, support_data, rules, min_confidence)
            else:
                calc_confidence(freqSet, H1, support_data, rules, min_confidence)
    return rules

def print_rules(rules):
    for r in rules:
        print('{} ==> {} (c={})'.format(*r))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Rule mining on sample data

# %%
MIN_CONFIDENCE = 0.5
# Mine association rules
association_rules = generateRules(L, support_data, min_confidence=MIN_CONFIDENCE)
print_rules(association_rules)
# Out:
# frozenset({'B'}) ==> frozenset({'C'}) (c=0.6666666666666666)
# frozenset({'C'}) ==> frozenset({'B'}) (c=0.6666666666666666)
# frozenset({'E'}) ==> frozenset({'C'}) (c=0.6666666666666666)
# frozenset({'C'}) ==> frozenset({'E'}) (c=0.6666666666666666)
# frozenset({'E'}) ==> frozenset({'B'}) (c=1.0)
# frozenset({'B'}) ==> frozenset({'E'}) (c=1.0)
# frozenset({'A'}) ==> frozenset({'C'}) (c=1.0)
# frozenset({'C'}) ==> frozenset({'A'}) (c=0.6666666666666666)
# frozenset({'C', 'E'}) ==> frozenset({'B'}) (c=1.0)
# frozenset({'B', 'E'}) ==> frozenset({'C'}) (c=0.6666666666666666)
# frozenset({'C', 'B'}) ==> frozenset({'E'}) (c=1.0)
# frozenset({'B'}) ==> frozenset({'C', 'E'}) (c=0.6666666666666666)
# frozenset({'C'}) ==> frozenset({'B', 'E'}) (c=0.6666666666666666)
# frozenset({'E'}) ==> frozenset({'C', 'B'}) (c=0.6666666666666666)
# frozenset({'C', 'E'}) ==> frozenset({'B'}) (c=1.0)
# frozenset({'B', 'E'}) ==> frozenset({'C'}) (c=0.6666666666666666)
# frozenset({'C', 'B'}) ==> frozenset({'E'}) (c=1.0)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### TODO Exploring confidence thresholds
#
# * Mine rules with a confidence threshold of 0.7
# * How many rules do we get at 0.7?
# >>5
# * How many do we get at 0.3?
# >>17
# * Can we use this for recommendation (e.g., Amazon, Netflix)?
# >> Yes

# %%
# TODO: replace the content of this cell with your Python solution
MIN_CONFIDENCE = 0.7
# Mine association rules
association_rules = generateRules(L, support_data, min_confidence=MIN_CONFIDENCE)
print_rules(association_rules)
# Out:
# frozenset({'E'}) ==> frozenset({'B'}) (c=1.0)
# frozenset({'B'}) ==> frozenset({'E'}) (c=1.0)
# frozenset({'A'}) ==> frozenset({'C'}) (c=1.0)
# frozenset({'C', 'E'}) ==> frozenset({'B'}) (c=1.0)
# frozenset({'C', 'B'}) ==> frozenset({'E'}) (c=1.0)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
MIN_CONFIDENCE = 0.3
# Mine association rules
association_rules = generateRules(L, support_data, min_confidence=MIN_CONFIDENCE)
print_rules(association_rules)
# Out:
# frozenset({'B'}) ==> frozenset({'C'}) (c=0.6666666666666666)
# frozenset({'C'}) ==> frozenset({'B'}) (c=0.6666666666666666)
# frozenset({'E'}) ==> frozenset({'C'}) (c=0.6666666666666666)
# frozenset({'C'}) ==> frozenset({'E'}) (c=0.6666666666666666)
# frozenset({'E'}) ==> frozenset({'B'}) (c=1.0)
# frozenset({'B'}) ==> frozenset({'E'}) (c=1.0)
# frozenset({'A'}) ==> frozenset({'C'}) (c=1.0)
# frozenset({'C'}) ==> frozenset({'A'}) (c=0.6666666666666666)
# frozenset({'C', 'E'}) ==> frozenset({'B'}) (c=1.0)
# frozenset({'B', 'E'}) ==> frozenset({'C'}) (c=0.6666666666666666)
# frozenset({'C', 'B'}) ==> frozenset({'E'}) (c=1.0)
# frozenset({'B'}) ==> frozenset({'C', 'E'}) (c=0.6666666666666666)
# frozenset({'C'}) ==> frozenset({'B', 'E'}) (c=0.6666666666666666)
# frozenset({'E'}) ==> frozenset({'C', 'B'}) (c=0.6666666666666666)
# frozenset({'C', 'E'}) ==> frozenset({'B'}) (c=1.0)
# frozenset({'B', 'E'}) ==> frozenset({'C'}) (c=0.6666666666666666)
# frozenset({'C', 'B'}) ==> frozenset({'E'}) (c=1.0)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## mlxtend library and apriori_python (Machine Learning Extend Library)

# %% [markdown]
# ## Association analysis using mlxtend library

# %%
#Install the library if it is not availab
#!pip install mlxtend
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori #find the freq itemset
from mlxtend.frequent_patterns import association_rules #find the rules
import pandas as pd
dataset =   [['A', 'C', 'D'], ['B', 'C', 'E'], ['A', 'B', 'C','E'],['B', 'E']]


oht = TransactionEncoder()
oht_ary = oht.fit(dataset).transform(dataset)
df = pd.DataFrame(oht_ary, columns=oht.columns_)
print (df)

frequent_itemsets = apriori(df, min_support=0.5, use_colnames=True)
print('Support values for candidate itemsets:\n', frequent_itemsets, '\n')


rules= association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
#rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.2)
#print (rules.as_matrix(columns=['antecedents','consequents','confidence']))
print(rules[['antecedents','consequents','confidence']])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        A      B      C      D      E
# 0   True  False   True   True  False
# 1  False   True   True  False   True
# 2   True   True   True  False   True
# 3  False   True  False  False   True
# Support values for candidate itemsets:
#     support   itemsets
# 0     0.50        (A)
# 1     0.75        (B)
# 2     0.75        (C)
# 3     0.75        (E)
# 4     0.50     (C, A)
# 5     0.50     (C, B)
# 6     0.75     (E, B)
# 7     0.50     (C, E)
# 8     0.50  (E, C, B)
#
#   antecedents consequents  confidence
# 0         (A)         (C)         1.0
# 1         (E)         (B)         1.0
# 2         (B)         (E)         1.0
# 3      (C, E)         (B)         1.0
# 4      (C, B)         (E)         1.0

# %% [markdown]
# ## Association analysis using apriori_python library

# %%
# !pip install apriori_python
from apriori_python import apriori
dataset =   [['A', 'C', 'D'], ['B', 'C', 'E'], ['A', 'B', 'C','E'],['B', 'E']]
freqItemSet, rules = apriori(dataset, minSup=0.7, minConf=0.0)

for r in rules:
    print('{} ==> {} (c={})'.format(*r))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Requirement already satisfied: apriori_python in /usr/local/lib/python3.10/dist-packages (1.0.4)
# {'B'} ==> {'E'} (c=1.0)
# {'E'} ==> {'B'} (c=1.0)

# %% [markdown]
# # Load the  supermarket transaction datasets
# ### Now Lets work on a real Grocery dataset

# %%
import csv
import pprint
file_name = 'Groceries.csv'
data_list = []
with open(file_name, 'r') as f:  #opens PW file
    reader = csv.reader(f)
    # Print every value of every row.
    for row in reader:
        row_list = []
        for value in row:
            if len(value.strip()) > 0 and value.strip() != '':
                row_list.append(value.strip())
        data_list.append(row_list)
pprint.pprint(data_list)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Streaming output truncated to the last 5000 lines.
#   'vegetables',
#   'vegetables',
#   'sandwich loaves',
#   'flour',
#   'butter',
#   'soap',
#   'sandwich loaves',
#   'vegetables',
#   'spaghetti sauce',
#   'poultry'],
#  ['sandwich loaves',
#   'waffles',
#   'sandwich loaves',
#   'pork',
#   'paper towels',
#   'bagels',
#   'tortillas',
#   'lunch meat',
#   'ice cream',
#   'dinner rolls',
#   'pork',
#   'cereals',
#   'hand soap',
#   'spaghetti sauce'],
#  ['beef',
#   'soda',
#   'dinner rolls',
#   'vegetables',
#   'all- purpose',
#   'sugar',
#   'hand soap',
#   'all- purpose',
#   'beef',
#   'mixes',
#   'eggs',
#   'yogurt',
#   'mixes',
#   'dinner rolls'],
#  ['soda',
#   'dishwashing liquid/detergent',
#   'dinner rolls',
#   'cheeses',
#   'milk',
#   'vegetables',
#   'vegetables',
#   'cheeses',
#   'aluminum foil',
#   'cheeses',
#   'aluminum foil',
#   'eggs',
#   'yogurt',
#   'coffee/tea'],
#  ['hand soap', 'paper towels', 'poultry', 'fruits', 'bagels', 'mixes'],
#  ['lunch meat',
#   'dishwashing liquid/detergent',
#   'spaghetti sauce',
#   'lunch meat',
#   'dinner rolls',
#   'dinner rolls',
#   'pork',
#   'shampoo',
#   'sandwich loaves',
#   'toilet paper',
#   'eggs',
#   'waffles',
#   'mixes',
#   'bagels'],
#  ['paper towels',
#   'tortillas',
#   'individual meals',
#   'all- purpose',
#   'soap',
#   'flour',
#   'shampoo',
#   'juice',
#   'sandwich loaves',
#   'aluminum foil',
#   'pasta',
#   'waffles',
#   'toilet paper',
#   'coffee/tea'],
#  ['lunch meat',
#   'vegetables',
#   'milk',
#   'eggs',
#   'paper towels',
#   'sugar',
#   'bagels',
#   'vegetables',
#   'cereals',
#   'vegetables',
#   'soap',
#   'aluminum foil',
#   'dishwashing liquid/detergent',
#   'waffles'],
#  ['beef',
#   'tortillas',
#   'butter',
#   'paper towels',
#   'eggs',
#   'all- purpose',
#   'cheeses',
#   'pasta',
#   'lunch meat',
#   'paper towels',
#   'spaghetti sauce',
#   'eggs',
#   'sandwich loaves',
#   'all- purpose'],
#  ['beef',
#   'aluminum foil',
#   'yogurt',
#   'flour',
#   'juice',
#   'flour',
#   'ice cream',
#   'poultry',
#   'milk',
#   'waffles',
#   'all- purpose',
#   'juice',
#   'lunch meat',
#   'dishwashing liquid/detergent'],
#  ['mixes',
#   'fruits',
#   'dishwashing liquid/detergent',
#   'hand soap',
#   'cereals',
#   'lunch meat',
#   'soap',
#   'waffles',
#   'sugar',
#   'lunch meat',
#   'shampoo',
#   'dishwashing liquid/detergent',
#   'butter',
#   'flour'],
#  ['waffles',
#   'ice cream',
#   'individual meals',
#   'all- purpose',
#   'soda',
#   'bagels',
#   'lunch meat',
#   'vegetables',
#   'dinner rolls',
#   'shampoo',
#   'flour',
#   'spaghetti sauce',
#   'all- purpose',
#   'juice'],
#  ['soda',
#   'toilet paper',
#   'individual meals',
#   'aluminum foil',
#   'coffee/tea',
#   'juice',
#   'butter',
#   'ice cream',
#   'ice cream'],
#  ['individual meals',
#   'soda',
#   'spaghetti sauce',
#   'pork',
#   'vegetables',
#   'spaghetti sauce',
#   'eggs',
#   'cheeses'],
#  ['vegetables',
#   'sandwich loaves',
#   'pasta',
#   'juice',
#   'aluminum foil',
#   'shampoo',
#   'soda',
#   'hand soap',
#   'milk',
#   'vegetables'],
#  ['fruits',
#   'pasta',
#   'milk',
#   'lunch meat',
#   'lunch meat',
#   'soda',
#   'milk',
#   'all- purpose',
#   'paper towels',
#   'vegetables',
#   'soda',
#   'yogurt',
#   'soap',
#   'spaghetti sauce'],
#  ['dinner rolls',
#   'fruits',
#   'eggs',
#   'shampoo',
#   'soda',
#   'bagels',
#   'paper towels'],
#  ['waffles',
#   'spaghetti sauce',
#   'sugar',
#   'hand soap',
#   'beef',
#   'juice',
#   'sandwich loaves',
#   'shampoo',
#   'aluminum foil',
#   'dinner rolls',
#   'shampoo',
#   'ice cream',
#   'pasta',
#   'vegetables'],
#  ['sandwich loaves',
#   'sandwich loaves',
#   'hand soap',
#   'poultry',
#   'ketchup',
#   'sugar',
#   'fruits',
#   'fruits',
#   'sandwich bags',
#   'cheeses',
#   'flour',
#   'vegetables',
#   'shampoo'],
#  ['ketchup',
#   'sandwich bags',
#   'dinner rolls',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'beef',
#   'cereals',
#   'poultry',
#   'pasta',
#   'spaghetti sauce',
#   'bagels',
#   'paper towels',
#   'sandwich bags',
#   'milk'],
#  ['ice cream',
#   'tortillas',
#   'pork',
#   'cheeses',
#   'cereals',
#   'coffee/tea',
#   'cheeses',
#   'yogurt',
#   'vegetables',
#   'vegetables',
#   'shampoo',
#   'dinner rolls',
#   'coffee/tea',
#   'waffles'],
#  ['ketchup',
#   'sandwich bags',
#   'waffles',
#   'toilet paper',
#   'pasta',
#   'individual meals',
#   'cheeses',
#   'shampoo',
#   'ice cream',
#   'pasta',
#   'individual meals',
#   'toilet paper',
#   'pork',
#   'poultry'],
#  ['all- purpose',
#   'cheeses',
#   'shampoo',
#   'waffles',
#   'mixes',
#   'individual meals',
#   'waffles',
#   'sandwich bags',
#   'spaghetti sauce',
#   'sandwich bags',
#   'pasta',
#   'shampoo',
#   'beef',
#   'ice cream'],
#  ['butter',
#   'all- purpose',
#   'laundry detergent',
#   'shampoo',
#   'coffee/tea',
#   'paper towels',
#   'soap',
#   'spaghetti sauce',
#   'cheeses',
#   'vegetables',
#   'sandwich loaves',
#   'individual meals',
#   'paper towels',
#   'dinner rolls'],
#  ['ice cream',
#   'individual meals',
#   'dishwashing liquid/detergent',
#   'spaghetti sauce',
#   'hand soap',
#   'eggs',
#   'soap',
#   'all- purpose',
#   'fruits',
#   'lunch meat',
#   'sugar',
#   'individual meals',
#   'sugar',
#   'vegetables'],
#  ['flour',
#   'milk',
#   'sandwich bags',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'cereals',
#   'yogurt',
#   'ice cream',
#   'spaghetti sauce',
#   'eggs',
#   'soda',
#   'soap',
#   'vegetables',
#   'vegetables'],
#  ['dinner rolls',
#   'eggs',
#   'spaghetti sauce',
#   'aluminum foil',
#   'soda',
#   'lunch meat',
#   'milk',
#   'milk',
#   'vegetables',
#   'toilet paper',
#   'coffee/tea',
#   'soap',
#   'dinner rolls',
#   'beef'],
#  ['sugar',
#   'sandwich bags',
#   'poultry',
#   'yogurt',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'individual meals',
#   'vegetables',
#   'vegetables',
#   'soap',
#   'bagels',
#   'spaghetti sauce',
#   'waffles',
#   'butter'],
#  ['cereals',
#   'beef',
#   'sugar',
#   'coffee/tea',
#   'coffee/tea',
#   'lunch meat',
#   'pasta',
#   'soap'],
#  ['laundry detergent',
#   'mixes',
#   'poultry',
#   'individual meals',
#   'bagels',
#   'vegetables',
#   'tortillas',
#   'juice',
#   'laundry detergent',
#   'waffles'],
#  ['pasta',
#   'soda',
#   'vegetables',
#   'vegetables',
#   'poultry',
#   'sandwich bags',
#   'poultry',
#   'cereals',
#   'vegetables',
#   'hand soap'],
#  ['coffee/tea', 'hand soap', 'ice cream', 'beef'],
#  ['yogurt',
#   'laundry detergent',
#   'laundry detergent',
#   'dinner rolls',
#   'pasta',
#   'flour',
#   'sugar',
#   'pasta',
#   'soda'],
#  ['dinner rolls',
#   'coffee/tea',
#   'sandwich loaves',
#   'ketchup',
#   'coffee/tea',
#   'beef',
#   'coffee/tea',
#   'coffee/tea'],
#  ['flour',
#   'coffee/tea',
#   'lunch meat',
#   'spaghetti sauce',
#   'cereals',
#   'sandwich loaves',
#   'vegetables',
#   'butter',
#   'flour',
#   'vegetables',
#   'ice cream',
#   'paper towels',
#   'paper towels',
#   'sandwich loaves'],
#  ['shampoo',
#   'pasta',
#   'mixes',
#   'tortillas',
#   'mixes',
#   'ketchup',
#   'juice',
#   'mixes',
#   'ice cream',
#   'ketchup',
#   'paper towels',
#   'laundry detergent',
#   'fruits',
#   'mixes'],
#  ['toilet paper',
#   'ice cream',
#   'cheeses',
#   'laundry detergent',
#   'lunch meat',
#   'soap',
#   'all- purpose',
#   'soap'],
#  ['vegetables',
#   'bagels',
#   'juice',
#   'vegetables',
#   'lunch meat',
#   'toilet paper',
#   'vegetables',
#   'poultry',
#   'pork',
#   'shampoo',
#   'hand soap',
#   'sandwich loaves',
#   'individual meals',
#   'yogurt'],
#  ['ice cream',
#   'sandwich bags',
#   'vegetables',
#   'sandwich bags',
#   'waffles',
#   'dinner rolls',
#   'tortillas',
#   'yogurt',
#   'bagels',
#   'cereals',
#   'juice',
#   'toilet paper',
#   'ice cream',
#   'paper towels'],
#  ['soap',
#   'vegetables',
#   'poultry',
#   'sugar',
#   'beef',
#   'aluminum foil',
#   'cereals',
#   'milk',
#   'flour',
#   'lunch meat'],
#  ['soda',
#   'beef',
#   'vegetables',
#   'vegetables',
#   'juice',
#   'vegetables',
#   'eggs',
#   'vegetables',
#   'dinner rolls',
#   'vegetables',
#   'ketchup',
#   'sugar',
#   'fruits',
#   'sugar'],
#  ['bagels', 'ice cream', 'shampoo', 'sugar'],
#  ['pork',
#   'waffles',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'ketchup',
#   'vegetables',
#   'individual meals',
#   'ice cream',
#   'spaghetti sauce',
#   'cheeses',
#   'ketchup',
#   'fruits',
#   'hand soap',
#   'eggs'],
#  ['individual meals',
#   'aluminum foil',
#   'dishwashing liquid/detergent',
#   'coffee/tea',
#   'dinner rolls',
#   'coffee/tea',
#   'cheeses'],
#  ['sandwich bags',
#   'cereals',
#   'aluminum foil',
#   'juice',
#   'soap',
#   'all- purpose',
#   'sugar',
#   'soda',
#   'juice',
#   'individual meals',
#   'beef',
#   'sugar',
#   'pork',
#   'laundry detergent'],
#  ['all- purpose',
#   'poultry',
#   'juice',
#   'cereals',
#   'sugar',
#   'fruits',
#   'coffee/tea',
#   'individual meals',
#   'dishwashing liquid/detergent',
#   'lunch meat',
#   'soap',
#   'laundry detergent',
#   'mixes',
#   'bagels'],
#  ['sandwich loaves',
#   'juice',
#   'ice cream',
#   'poultry',
#   'vegetables',
#   'mixes',
#   'shampoo',
#   'juice',
#   'laundry detergent',
#   'pasta',
#   'mixes',
#   'sandwich bags',
#   'vegetables',
#   'yogurt'],
#  ['vegetables',
#   'juice',
#   'sandwich loaves',
#   'coffee/tea',
#   'eggs',
#   'lunch meat',
#   'individual meals',
#   'paper towels',
#   'sandwich bags',
#   'fruits',
#   'sandwich bags',
#   'juice',
#   'laundry detergent',
#   'aluminum foil'],
#  ['beef',
#   'ice cream',
#   'dinner rolls',
#   'cereals',
#   'sandwich loaves',
#   'laundry detergent',
#   'soap',
#   'spaghetti sauce',
#   'individual meals',
#   'laundry detergent',
#   'sandwich loaves',
#   'sandwich bags',
#   'cheeses',
#   'soda'],
#  ['dishwashing liquid/detergent',
#   'butter',
#   'bagels',
#   'fruits',
#   'shampoo',
#   'cheeses',
#   'all- purpose',
#   'coffee/tea',
#   'dinner rolls',
#   'laundry detergent'],
#  ['fruits',
#   'vegetables',
#   'soap',
#   'fruits',
#   'eggs',
#   'butter',
#   'mixes',
#   'spaghetti sauce',
#   'poultry',
#   'all- purpose',
#   'dishwashing liquid/detergent',
#   'beef',
#   'cheeses',
#   'vegetables'],
#  ['ice cream',
#   'paper towels',
#   'pork',
#   'mixes',
#   'vegetables',
#   'aluminum foil',
#   'spaghetti sauce',
#   'cereals',
#   'ice cream',
#   'sandwich loaves',
#   'toilet paper',
#   'toilet paper',
#   'eggs',
#   'vegetables'],
#  ['sandwich loaves',
#   'milk',
#   'waffles',
#   'soda',
#   'vegetables',
#   'sugar',
#   'mixes',
#   'soda',
#   'milk',
#   'yogurt',
#   'toilet paper',
#   'sandwich loaves',
#   'lunch meat',
#   'individual meals'],
#  ['laundry detergent',
#   'bagels',
#   'pasta',
#   'spaghetti sauce',
#   'ice cream',
#   'eggs',
#   'pasta',
#   'cereals',
#   'soda',
#   'spaghetti sauce',
#   'vegetables',
#   'waffles',
#   'hand soap',
#   'pork'],
#  ['tortillas',
#   'soap',
#   'shampoo',
#   'soda',
#   'yogurt',
#   'cereals',
#   'sandwich loaves',
#   'sandwich loaves',
#   'beef',
#   'poultry',
#   'all- purpose',
#   'fruits',
#   'paper towels',
#   'tortillas'],
#  ['waffles',
#   'aluminum foil',
#   'beef',
#   'beef',
#   'sugar',
#   'individual meals',
#   'beef',
#   'yogurt',
#   'yogurt',
#   'fruits',
#   'pork',
#   'cereals',
#   'paper towels',
#   'beef'],
#  ['shampoo',
#   'tortillas',
#   'milk',
#   'mixes',
#   'milk',
#   'coffee/tea',
#   'cereals',
#   'coffee/tea',
#   'mixes',
#   'all- purpose',
#   'soda',
#   'tortillas',
#   'beef',
#   'lunch meat'],
#  ['lunch meat',
#   'soap',
#   'soda',
#   'hand soap',
#   'butter',
#   'milk',
#   'lunch meat',
#   'lunch meat',
#   'ice cream',
#   'butter',
#   'lunch meat',
#   'dishwashing liquid/detergent',
#   'laundry detergent',
#   'paper towels'],
#  ['aluminum foil',
#   'coffee/tea',
#   'spaghetti sauce',
#   'lunch meat',
#   'cheeses',
#   'spaghetti sauce',
#   'soda',
#   'sugar',
#   'spaghetti sauce',
#   'ice cream',
#   'pasta',
#   'vegetables',
#   'flour',
#   'laundry detergent'],
#  ['fruits',
#   'coffee/tea',
#   'beef',
#   'lunch meat',
#   'vegetables',
#   'sandwich loaves',
#   'juice',
#   'individual meals',
#   'yogurt',
#   'pasta',
#   'hand soap',
#   'cheeses',
#   'waffles',
#   'vegetables'],
#  ['cheeses',
#   'toilet paper',
#   'toilet paper',
#   'juice',
#   'all- purpose',
#   'fruits',
#   'lunch meat',
#   'sugar',
#   'beef',
#   'toilet paper',
#   'sugar',
#   'pork',
#   'beef',
#   'laundry detergent'],
#  ['cereals',
#   'individual meals',
#   'hand soap',
#   'soda',
#   'juice',
#   'pork',
#   'eggs',
#   'tortillas',
#   'tortillas',
#   'flour'],
#  ['milk',
#   'dishwashing liquid/detergent',
#   'flour',
#   'yogurt',
#   'milk',
#   'all- purpose',
#   'all- purpose',
#   'waffles',
#   'mixes',
#   'cheeses',
#   'cheeses',
#   'hand soap',
#   'aluminum foil',
#   'vegetables'],
#  ['vegetables',
#   'toilet paper',
#   'juice',
#   'waffles',
#   'bagels',
#   'vegetables',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'beef',
#   'dinner rolls',
#   'sandwich bags',
#   'sandwich loaves',
#   'pork',
#   'yogurt'],
#  ['lunch meat',
#   'aluminum foil',
#   'shampoo',
#   'dinner rolls',
#   'toilet paper',
#   'sugar',
#   'soda',
#   'milk',
#   'individual meals',
#   'soda',
#   'vegetables',
#   'spaghetti sauce',
#   'milk',
#   'soda'],
#  ['juice',
#   'coffee/tea',
#   'shampoo',
#   'pasta',
#   'dishwashing liquid/detergent',
#   'hand soap',
#   'soap',
#   'pasta',
#   'all- purpose',
#   'sandwich loaves',
#   'sandwich bags',
#   'ketchup',
#   'waffles',
#   'cereals'],
#  ['yogurt',
#   'lunch meat',
#   'soap',
#   'individual meals',
#   'vegetables',
#   'shampoo',
#   'aluminum foil',
#   'milk',
#   'waffles',
#   'soap',
#   'paper towels',
#   'flour',
#   'shampoo'],
#  ['fruits',
#   'soda',
#   'pork',
#   'yogurt',
#   'shampoo',
#   'sandwich loaves',
#   'sandwich bags',
#   'sugar',
#   'vegetables'],
#  ['soda',
#   'cheeses',
#   'pasta',
#   'sandwich bags',
#   'bagels',
#   'sugar',
#   'beef',
#   'butter',
#   'all- purpose',
#   'all- purpose',
#   'sandwich loaves',
#   'juice',
#   'toilet paper',
#   'pork'],
#  ['aluminum foil',
#   'soda',
#   'spaghetti sauce',
#   'cheeses',
#   'cheeses',
#   'sandwich bags',
#   'vegetables',
#   'vegetables',
#   'cheeses',
#   'toilet paper',
#   'waffles',
#   'vegetables',
#   'all- purpose',
#   'flour'],
#  ['waffles',
#   'vegetables',
#   'soap',
#   'ice cream',
#   'lunch meat',
#   'individual meals',
#   'all- purpose',
#   'pasta',
#   'paper towels',
#   'juice',
#   'vegetables',
#   'poultry',
#   'spaghetti sauce',
#   'aluminum foil'],
#  ['soap',
#   'bagels',
#   'tortillas',
#   'eggs',
#   'sandwich bags',
#   'poultry',
#   'toilet paper',
#   'dishwashing liquid/detergent',
#   'pork',
#   'cheeses',
#   'spaghetti sauce',
#   'vegetables',
#   'fruits',
#   'sandwich bags'],
#  ['laundry detergent',
#   'pasta',
#   'hand soap',
#   'eggs',
#   'milk',
#   'hand soap',
#   'waffles',
#   'beef',
#   'bagels',
#   'sandwich bags',
#   'soda',
#   'juice',
#   'soap',
#   'cereals'],
#  ['all- purpose',
#   'ketchup',
#   'yogurt',
#   'ice cream',
#   'soda',
#   'ice cream',
#   'vegetables',
#   'vegetables',
#   'laundry detergent',
#   'ice cream',
#   'vegetables',
#   'spaghetti sauce',
#   'soap',
#   'vegetables'],
#  ['coffee/tea',
#   'sandwich loaves',
#   'juice',
#   'bagels',
#   'individual meals',
#   'juice',
#   'spaghetti sauce',
#   'shampoo',
#   'butter',
#   'sandwich bags',
#   'tortillas',
#   'poultry'],
#  ['juice',
#   'tortillas',
#   'aluminum foil',
#   'fruits',
#   'ice cream',
#   'eggs',
#   'milk',
#   'bagels',
#   'cereals',
#   'shampoo',
#   'ice cream',
#   'beef',
#   'pork',
#   'individual meals'],
#  ['aluminum foil',
#   'fruits',
#   'ice cream',
#   'sandwich loaves',
#   'tortillas',
#   'cereals',
#   'cereals',
#   'paper towels',
#   'aluminum foil',
#   'vegetables',
#   'cereals',
#   'toilet paper',
#   'cereals',
#   'milk'],
#  ['poultry',
#   'yogurt',
#   'eggs',
#   'soap',
#   'sugar',
#   'ice cream',
#   'shampoo',
#   'yogurt',
#   'waffles',
#   'milk',
#   'bagels',
#   'soda',
#   'bagels',
#   'cereals'],
#  ['individual meals',
#   'beef',
#   'lunch meat',
#   'ice cream',
#   'individual meals',
#   'cheeses',
#   'vegetables',
#   'vegetables',
#   'coffee/tea',
#   'cereals',
#   'eggs'],
#  ['bagels',
#   'poultry',
#   'yogurt',
#   'aluminum foil',
#   'mixes',
#   'cheeses',
#   'laundry detergent',
#   'vegetables',
#   'vegetables',
#   'pork',
#   'waffles',
#   'vegetables',
#   'sandwich bags',
#   'ketchup'],
#  ['ice cream',
#   'poultry',
#   'mixes',
#   'aluminum foil',
#   'pasta',
#   'laundry detergent',
#   'laundry detergent',
#   'sugar',
#   'cereals',
#   'vegetables',
#   'pork',
#   'spaghetti sauce',
#   'mixes',
#   'flour'],
#  ['yogurt',
#   'sugar',
#   'yogurt',
#   'ketchup',
#   'tortillas',
#   'mixes',
#   'juice',
#   'bagels',
#   'coffee/tea',
#   'ice cream',
#   'shampoo',
#   'dinner rolls',
#   'all- purpose',
#   'butter'],
#  ['toilet paper',
#   'juice',
#   'sugar',
#   'shampoo',
#   'eggs',
#   'waffles',
#   'ice cream',
#   'hand soap',
#   'beef',
#   'vegetables'],
#  ['shampoo',
#   'laundry detergent',
#   'spaghetti sauce',
#   'mixes',
#   'sandwich loaves',
#   'aluminum foil',
#   'juice',
#   'cereals',
#   'eggs',
#   'shampoo',
#   'poultry',
#   'juice',
#   'yogurt',
#   'cereals'],
#  ['mixes',
#   'milk',
#   'soda',
#   'poultry',
#   'sugar',
#   'milk',
#   'sandwich bags',
#   'fruits',
#   'bagels',
#   'sugar',
#   'laundry detergent',
#   'tortillas',
#   'poultry',
#   'sugar'],
#  ['eggs',
#   'fruits',
#   'individual meals',
#   'tortillas',
#   'flour',
#   'ice cream',
#   'aluminum foil'],
#  ['toilet paper',
#   'sandwich bags',
#   'bagels',
#   'waffles',
#   'cereals',
#   'mixes',
#   'dishwashing liquid/detergent',
#   'lunch meat',
#   'cheeses',
#   'sandwich loaves',
#   'tortillas',
#   'flour',
#   'soda',
#   'cheeses'],
#  ['waffles',
#   'spaghetti sauce',
#   'poultry',
#   'vegetables',
#   'beef',
#   'vegetables',
#   'flour',
#   'coffee/tea',
#   'ketchup',
#   'vegetables',
#   'cereals',
#   'pasta',
#   'eggs',
#   'spaghetti sauce'],
#  ['butter',
#   'eggs',
#   'aluminum foil',
#   'cereals',
#   'cheeses',
#   'fruits',
#   'aluminum foil',
#   'cereals',
#   'dinner rolls',
#   'aluminum foil',
#   'mixes',
#   'pork',
#   'soap',
#   'shampoo'],
#  ['dishwashing liquid/detergent',
#   'cereals',
#   'fruits',
#   'pasta',
#   'ketchup',
#   'poultry',
#   'aluminum foil',
#   'aluminum foil',
#   'individual meals',
#   'yogurt',
#   'waffles',
#   'butter',
#   'paper towels',
#   'all- purpose'],
#  ['dishwashing liquid/detergent',
#   'poultry',
#   'dinner rolls',
#   'bagels',
#   'fruits',
#   'shampoo',
#   'ketchup'],
#  ['beef', 'shampoo', 'vegetables', 'waffles', 'lunch meat'],
#  ['vegetables',
#   'dinner rolls',
#   'hand soap',
#   'waffles',
#   'vegetables',
#   'butter',
#   'vegetables',
#   'flour',
#   'beef',
#   'ice cream',
#   'butter',
#   'individual meals',
#   'vegetables',
#   'cheeses'],
#  ['bagels',
#   'poultry',
#   'dishwashing liquid/detergent',
#   'coffee/tea',
#   'eggs',
#   'bagels',
#   'mixes',
#   'all- purpose',
#   'bagels',
#   'ice cream',
#   'soda',
#   'vegetables',
#   'vegetables',
#   'sandwich loaves'],
#  ['spaghetti sauce', 'lunch meat', 'dinner rolls', 'mixes'],
#  ['sandwich loaves',
#   'yogurt',
#   'spaghetti sauce',
#   'aluminum foil',
#   'poultry',
#   'soda',
#   'flour',
#   'flour',
#   'ketchup',
#   'individual meals',
#   'cheeses',
#   'vegetables',
#   'toilet paper',
#   'soap'],
#  ['dishwashing liquid/detergent',
#   'vegetables',
#   'poultry',
#   'vegetables',
#   'milk',
#   'mixes',
#   'bagels',
#   'sandwich loaves',
#   'pasta',
#   'ice cream',
#   'individual meals',
#   'hand soap',
#   'lunch meat',
#   'dishwashing liquid/detergent'],
#  ['cereals',
#   'waffles',
#   'tortillas',
#   'spaghetti sauce',
#   'toilet paper',
#   'dishwashing liquid/detergent',
#   'toilet paper',
#   'individual meals',
#   'pork',
#   'toilet paper',
#   'poultry',
#   'spaghetti sauce',
#   'hand soap',
#   'fruits'],
#  ['bagels',
#   'individual meals',
#   'sandwich bags',
#   'vegetables',
#   'vegetables',
#   'vegetables',
#   'ketchup',
#   'laundry detergent',
#   'soda',
#   'shampoo',
#   'flour',
#   'tortillas',
#   'yogurt',
#   'waffles'],
#  ['ice cream',
#   'tortillas',
#   'soda',
#   'hand soap',
#   'tortillas',
#   'bagels',
#   'sandwich bags',
#   'sandwich bags',
#   'milk',
#   'sandwich bags',
#   'shampoo'],
#  ['sugar',
#   'waffles',
#   'ketchup',
#   'fruits',
#   'butter',
#   'flour',
#   'dinner rolls',
#   'vegetables',
#   'vegetables',
#   'spaghetti sauce',
#   'aluminum foil',
#   'eggs'],
#  ['sandwich loaves',
#   'paper towels',
#   'lunch meat',
#   'sandwich loaves',
#   'flour',
#   'laundry detergent',
#   'soda',
#   'tortillas',
#   'soda',
#   'waffles',
#   'paper towels',
#   'sugar',
#   'vegetables',
#   'dinner rolls'],
#  ['yogurt',
#   'cheeses',
#   'coffee/tea',
#   'coffee/tea',
#   'vegetables',
#   'dinner rolls',
#   'cereals',
#   'dinner rolls',
#   'laundry detergent',
#   'lunch meat',
#   'vegetables',
#   'lunch meat',
#   'tortillas',
#   'cereals'],
#  ['sugar', 'toilet paper', 'soap', 'lunch meat', 'butter', 'sugar'],
#  ['sandwich loaves',
#   'soap',
#   'soap',
#   'sandwich loaves',
#   'laundry detergent',
#   'milk',
#   'eggs',
#   'ice cream',
#   'pork',
#   'toilet paper',
#   'soda',
#   'sandwich loaves',
#   'mixes'],
#  ['ice cream',
#   'laundry detergent',
#   'juice',
#   'cereals',
#   'ice cream',
#   'coffee/tea',
#   'ketchup',
#   'all- purpose',
#   'shampoo',
#   'soda',
#   'milk',
#   'dinner rolls',
#   'vegetables',
#   'tortillas'],
#  ['vegetables',
#   'fruits',
#   'vegetables',
#   'beef',
#   'ketchup',
#   'milk',
#   'paper towels',
#   'milk',
#   'soap',
#   'vegetables',
#   'soda',
#   'all- purpose',
#   'waffles',
#   'pork'],
#  ['yogurt',
#   'soda',
#   'soap',
#   'waffles',
#   'aluminum foil',
#   'soap',
#   'pork',
#   'cereals',
#   'coffee/tea',
#   'paper towels',
#   'cheeses',
#   'eggs',
#   'flour'],
#  ['sugar',
#   'milk',
#   'coffee/tea',
#   'hand soap',
#   'aluminum foil',
#   'dinner rolls',
#   'poultry',
#   'mixes',
#   'laundry detergent',
#   'butter',
#   'vegetables',
#   'ketchup',
#   'lunch meat',
#   'butter'],
#  ['toilet paper',
#   'toilet paper',
#   'toilet paper',
#   'lunch meat',
#   'soda',
#   'individual meals',
#   'waffles',
#   'soda',
#   'pork',
#   'dishwashing liquid/detergent',
#   'coffee/tea',
#   'ice cream',
#   'butter',
#   'eggs'],
#  ['spaghetti sauce',
#   'waffles',
#   'cheeses',
#   'pork',
#   'cereals',
#   'coffee/tea',
#   'cereals',
#   'sandwich bags',
#   'cheeses',
#   'aluminum foil',
#   'poultry',
#   'sandwich loaves',
#   'lunch meat',
#   'bagels'],
#  ['hand soap',
#   'dishwashing liquid/detergent',
#   'waffles',
#   'laundry detergent',
#   'flour',
#   'vegetables',
#   'cereals',
#   'shampoo',
#   'ice cream',
#   'shampoo',
#   'sugar',
#   'all- purpose',
#   'yogurt',
#   'milk'],
#  ['lunch meat',
#   'juice',
#   'lunch meat',
#   'vegetables',
#   'butter',
#   'waffles',
#   'toilet paper',
#   'spaghetti sauce',
#   'pork',
#   'bagels',
#   'beef',
#   'pork',
#   'shampoo',
#   'mixes'],
#  ['individual meals',
#   'lunch meat',
#   'poultry',
#   'hand soap',
#   'eggs',
#   'dinner rolls',
#   'paper towels',
#   'yogurt',
#   'toilet paper',
#   'ice cream',
#   'all- purpose',
#   'sugar',
#   'vegetables',
#   'milk'],
#  ['hand soap',
#   'individual meals',
#   'beef',
#   'yogurt',
#   'tortillas',
#   'mixes',
#   'vegetables',
#   'cereals',
#   'toilet paper',
#   'lunch meat',
#   'aluminum foil',
#   'vegetables',
#   'yogurt',
#   'vegetables'],
#  ['tortillas',
#   'beef',
#   'cereals',
#   'ketchup',
#   'poultry',
#   'sandwich bags',
#   'poultry',
#   'all- purpose',
#   'vegetables',
#   'pasta',
#   'pasta',
#   'individual meals',
#   'paper towels',
#   'juice'],
#  ['fruits',
#   'lunch meat',
#   'paper towels',
#   'paper towels',
#   'eggs',
#   'yogurt',
#   'sandwich bags',
#   'butter',
#   'all- purpose',
#   'eggs',
#   'dishwashing liquid/detergent',
#   'shampoo',
#   'bagels',
#   'ice cream'],
#  ['shampoo',
#   'all- purpose',
#   'dinner rolls',
#   'coffee/tea',
#   'hand soap',
#   'aluminum foil'],
#  ['vegetables',
#   'soap',
#   'vegetables',
#   'ketchup',
#   'mixes',
#   'individual meals',
#   'laundry detergent',
#   'eggs',
#   'bagels',
#   'vegetables',
#   'pasta',
#   'juice',
#   'soap',
#   'mixes'],
#  ['aluminum foil',
#   'laundry detergent',
#   'soap',
#   'sugar',
#   'eggs',
#   'sandwich bags',
#   'cheeses',
#   'sugar',
#   'eggs',
#   'bagels',
#   'dinner rolls',
#   'sandwich bags',
#   'eggs',
#   'shampoo'],
#  ['ice cream',
#   'ketchup',
#   'cheeses',
#   'soap',
#   'sugar',
#   'ice cream',
#   'individual meals',
#   'laundry detergent',
#   'spaghetti sauce',
#   'pork',
#   'paper towels',
#   'soap',
#   'beef',
#   'vegetables'],
#  ['butter',
#   'spaghetti sauce',
#   'pasta',
#   'ketchup',
#   'all- purpose',
#   'paper towels',
#   'individual meals',
#   'soda',
#   'soda',
#   'yogurt',
#   'spaghetti sauce',
#   'vegetables',
#   'soap',
#   'milk'],
#  ['soap',
#   'bagels',
#   'pork',
#   'all- purpose',
#   'paper towels',
#   'butter',
#   'milk',
#   'paper towels',
#   'mixes',
#   'eggs',
#   'cheeses'],
#  ['sandwich bags',
#   'sandwich bags',
#   'sandwich bags',
#   'butter',
#   'sandwich loaves'],
#  ['soap',
#   'pork',
#   'vegetables',
#   'butter',
#   'paper towels',
#   'sandwich bags',
#   'vegetables',
#   'vegetables',
#   'flour',
#   'cereals',
#   'all- purpose',
#   'all- purpose',
#   'toilet paper',
#   'cereals'],
#  ['milk',
#   'dishwashing liquid/detergent',
#   'eggs',
#   'vegetables',
#   'yogurt',
#   'waffles',
#   'tortillas',
#   'butter',
#   'individual meals'],
#  ['soda',
#   'eggs',
#   'bagels',
#   'eggs',
#   'dinner rolls',
#   'laundry detergent',
#   'soda',
#   'paper towels',
#   'toilet paper',
#   'soap',
#   'dinner rolls',
#   'pasta',
#   'vegetables'],
#  ['lunch meat',
#   'soap',
#   'hand soap',
#   'vegetables',
#   'sandwich loaves',
#   'aluminum foil',
#   'ketchup',
#   'waffles',
#   'mixes',
#   'milk',
#   'flour',
#   'ketchup',
#   'vegetables',
#   'pork'],
#  ['sandwich bags',
#   'sugar',
#   'cheeses',
#   'milk',
#   'ketchup',
#   'flour',
#   'sandwich loaves',
#   'vegetables',
#   'soda',
#   'spaghetti sauce'],
#  ['flour',
#   'pork',
#   'spaghetti sauce',
#   'coffee/tea',
#   'cheeses',
#   'ketchup',
#   'cheeses',
#   'tortillas',
#   'aluminum foil',
#   'milk',
#   'dinner rolls',
#   'bagels',
#   'individual meals'],
#  ['hand soap',
#   'coffee/tea',
#   'paper towels',
#   'soda',
#   'cheeses',
#   'soap',
#   'waffles',
#   'soda',
#   'milk',
#   'yogurt',
#   'pork',
#   'coffee/tea',
#   'cheeses',
#   'poultry'],
#  ['sugar',
#   'sandwich loaves',
#   'cereals',
#   'paper towels',
#   'vegetables',
#   'pasta',
#   'shampoo',
#   'paper towels',
#   'shampoo',
#   'sugar',
#   'shampoo',
#   'bagels',
#   'coffee/tea',
#   'sugar'],
#  ['paper towels',
#   'bagels',
#   'coffee/tea',
#   'cheeses',
#   'sugar',
#   'tortillas',
#   'vegetables',
#   'flour',
#   'laundry detergent',
#   'eggs',
#   'lunch meat',
#   'sugar',
#   'dishwashing liquid/detergent',
#   'dishwashing liquid/detergent'],
#  ['vegetables',
#   'beef',
#   'pasta',
#   'eggs',
#   'sandwich loaves',
#   'cheeses',
#   'poultry',
#   'cheeses',
#   'waffles',
#   'fruits',
#   'soap',
#   'hand soap',
#   'beef',
#   'poultry'],
#  ['poultry',
#   'spaghetti sauce',
#   'individual meals',
#   'pork',
#   'sugar',
#   'tortillas',
#   'soap',
#   'ketchup',
#   'poultry',
#   'juice',
#   'fruits',
#   'paper towels',
#   'soda',
#   'yogurt'],
#  ['ice cream',
#   'bagels',
#   'sugar',
#   'sugar',
#   'laundry detergent',
#   'butter',
#   'individual meals',
#   'cereals',
#   'tortillas',
#   'cereals',
#   'laundry detergent',
#   'all- purpose',
#   'vegetables',
#   'tortillas'],
#  ['eggs',
#   'cereals',
#   'vegetables',
#   'pork',
#   'individual meals',
#   'all- purpose',
#   'juice',
#   'all- purpose',
#   'all- purpose',
#   'aluminum foil',
#   'spaghetti sauce',
#   'paper towels',
#   'sandwich bags',
#   'yogurt'],
#  ['sandwich loaves',
#   'yogurt',
#   'butter',
#   'flour',
#   'tortillas',
#   'all- purpose',
#   'beef',
#   'pasta',
#   'ketchup',
#   'sugar',
#   'individual meals',
#   'aluminum foil',
#   'lunch meat',
#   'soap'],
#  ['individual meals',
#   'pork',
#   'shampoo',
#   'mixes',
#   'hand soap',
#   'individual meals',
#   'aluminum foil',
#   'sandwich loaves',
#   'pork',
#   'sandwich bags',
#   'tortillas',
#   'beef',
#   'yogurt',
#   'butter'],
#  ['milk',
#   'lunch meat',
#   'butter',
#   'laundry detergent',
#   'spaghetti sauce',
#   'cheeses',
#   'soap',
#   'ice cream'],
#  ['tortillas',
#   'vegetables',
#   'toilet paper',
#   'yogurt',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'laundry detergent',
#   'sandwich bags',
#   'lunch meat',
#   'milk',
#   'tortillas',
#   'laundry detergent',
#   'vegetables',
#   'dinner rolls'],
#  ['butter',
#   'soda',
#   'butter',
#   'pork',
#   'hand soap',
#   'lunch meat',
#   'butter',
#   'paper towels',
#   'eggs',
#   'vegetables',
#   'poultry',
#   'poultry',
#   'soda',
#   'coffee/tea'],
#  ['aluminum foil',
#   'soda',
#   'hand soap',
#   'toilet paper',
#   'dishwashing liquid/detergent',
#   'milk',
#   'hand soap',
#   'ice cream',
#   'soap',
#   'pork',
#   'mixes',
#   'all- purpose'],
#  ['shampoo',
#   'flour',
#   'milk',
#   'aluminum foil',
#   'ketchup',
#   'pasta',
#   'laundry detergent',
#   'mixes',
#   'individual meals',
#   'pork',
#   'aluminum foil'],
#  ['flour',
#   'coffee/tea',
#   'shampoo',
#   'lunch meat',
#   'bagels',
#   'tortillas',
#   'hand soap',
#   'beef',
#   'aluminum foil',
#   'all- purpose',
#   'soap',
#   'waffles'],
#  ['pork',
#   'ice cream',
#   'all- purpose',
#   'toilet paper',
#   'bagels',
#   'eggs',
#   'individual meals',
#   'aluminum foil',
#   'vegetables',
#   'sandwich loaves',
#   'ketchup',
#   'lunch meat',
#   'laundry detergent',
#   'fruits'],
#  ['cheeses',
#   'fruits',
#   'mixes',
#   'flour',
#   'aluminum foil',
#   'soap',
#   'eggs',
#   'dishwashing liquid/detergent',
#   'juice',
#   'milk',
#   'coffee/tea',
#   'hand soap'],
#  ['paper towels',
#   'all- purpose',
#   'soda',
#   'butter',
#   'ketchup',
#   'waffles',
#   'soap',
#   'individual meals',
#   'laundry detergent',
#   'dishwashing liquid/detergent',
#   'lunch meat',
#   'vegetables',
#   'ketchup',
#   'vegetables'],
#  ['bagels',
#   'dinner rolls',
#   'ketchup',
#   'paper towels',
#   'tortillas',
#   'eggs',
#   'fruits',
#   'bagels',
#   'eggs',
#   'laundry detergent',
#   'cereals',
#   'toilet paper',
#   'eggs',
#   'vegetables'],
#  ['waffles',
#   'flour',
#   'soap',
#   'sugar',
#   'tortillas',
#   'soda',
#   'juice',
#   'all- purpose',
#   'milk',
#   'spaghetti sauce',
#   'fruits',
#   'hand soap',
#   'mixes',
#   'waffles'],
#  ['sandwich bags',
#   'bagels',
#   'eggs',
#   'shampoo',
#   'pasta',
#   'sugar',
#   'dinner rolls',
#   'lunch meat',
#   'sandwich loaves',
#   'vegetables',
#   'hand soap',
#   'lunch meat',
#   'all- purpose',
#   'sandwich bags'],
#  ['ketchup', 'individual meals', 'milk', 'coffee/tea', 'eggs'],
#  ['hand soap',
#   'laundry detergent',
#   'sugar',
#   'soap',
#   'individual meals',
#   'flour',
#   'lunch meat',
#   'butter',
#   'sandwich bags',
#   'all- purpose',
#   'hand soap',
#   'sugar',
#   'sandwich loaves',
#   'aluminum foil'],
#  ['pasta',
#   'aluminum foil',
#   'sugar',
#   'butter',
#   'soda',
#   'flour',
#   'soap',
#   'cheeses',
#   'shampoo',
#   'aluminum foil',
#   'pork',
#   'eggs',
#   'mixes',
#   'dinner rolls'],
#  ['poultry',
#   'pasta',
#   'vegetables',
#   'cereals',
#   'eggs',
#   'sugar',
#   'sugar',
#   'pork'],
#  ['beef', 'aluminum foil', 'eggs', 'milk', 'dinner rolls'],
#  ['pork',
#   'sandwich loaves',
#   'butter',
#   'tortillas',
#   'spaghetti sauce',
#   'dinner rolls',
#   'lunch meat',
#   'coffee/tea',
#   'dinner rolls',
#   'coffee/tea',
#   'vegetables',
#   'soap',
#   'flour',
#   'coffee/tea'],
#  ['cereals',
#   'dishwashing liquid/detergent',
#   'paper towels',
#   'pork',
#   'yogurt',
#   'soda',
#   'mixes',
#   'eggs',
#   'mixes',
#   'dinner rolls',
#   'fruits',
#   'soap',
#   'beef',
#   'dinner rolls'],
#  ['pork',
#   'hand soap',
#   'sugar',
#   'waffles',
#   'sandwich bags',
#   'all- purpose',
#   'all- purpose',
#   'pasta',
#   'dinner rolls',
#   'bagels',
#   'mixes',
#   'sandwich bags',
#   'beef',
#   'tortillas'],
#  ['sandwich bags',
#   'vegetables',
#   'soda',
#   'bagels',
#   'all- purpose',
#   'dishwashing liquid/detergent',
#   'aluminum foil',
#   'fruits',
#   'waffles',
#   'cereals',
#   'hand soap',
#   'vegetables',
#   'mixes',
#   'vegetables'],
#  ['poultry',
#   'vegetables',
#   'milk',
#   'butter',
#   'hand soap',
#   'bagels',
#   'individual meals',
#   'all- purpose',
#   'cereals',
#   'pasta',
#   'laundry detergent',
#   'toilet paper',
#   'lunch meat',
#   'beef'],
#  ['vegetables',
#   'flour',
#   'cheeses',
#   'cheeses',
#   'juice',
#   'cereals',
#   'ice cream',
#   'flour',
#   'spaghetti sauce',
#   'spaghetti sauce',
#   'vegetables',
#   'soda',
#   'hand soap',
#   'sugar'],
#  ['individual meals',
#   'butter',
#   'ketchup',
#   'dishwashing liquid/detergent',
#   'sandwich loaves',
#   'individual meals',
#   'toilet paper',
#   'lunch meat',
#   'vegetables',
#   'hand soap',
#   'bagels',
#   'shampoo',
#   'ketchup',
#   'coffee/tea'],
#  ['fruits',
#   'coffee/tea',
#   'pasta',
#   'sandwich loaves',
#   'juice',
#   'ice cream',
#   'vegetables',
#   'yogurt',
#   'cereals',
#   'cheeses',
#   'hand soap',
#   'yogurt',
#   'tortillas',
#   'soap'],
#  ['pork',
#   'soap',
#   'soda',
#   'paper towels',
#   'butter',
#   'dishwashing liquid/detergent',
#   'dinner rolls',
#   'lunch meat'],
#  ['yogurt', 'bagels', 'yogurt', 'cheeses', 'spaghetti sauce', 'yogurt'],
#  ['flour',
#   'sugar',
#   'coffee/tea',
#   'shampoo',
#   'sandwich loaves',
#   'spaghetti sauce',
#   'juice',
#   'dinner rolls',
#   'laundry detergent',
#   'lunch meat',
#   'poultry',
#   'pork',
#   'juice',
#   'toilet paper'],
#  ['vegetables',
#   'butter',
#   'vegetables',
#   'cereals',
#   'laundry detergent',
#   'poultry',
#   'mixes',
#   'juice',
#   'individual meals',
#   'cheeses',
#   'fruits',
#   'spaghetti sauce',
#   'aluminum foil',
#   'vegetables'],
#  ['juice',
#   'ketchup',
#   'sandwich loaves',
#   'soap',
#   'pork',
#   'vegetables',
#   'poultry',
#   'bagels',
#   'sandwich loaves',
#   'yogurt',
#   'ketchup',
#   'vegetables',
#   'pork',
#   'shampoo'],
#  ['cheeses',
#   'soap',
#   'vegetables',
#   'waffles',
#   'cheeses',
#   'lunch meat',
#   'soap',
#   'all- purpose',
#   'soap',
#   'sugar',
#   'ice cream',
#   'cereals',
#   'hand soap',
#   'pork'],
#  ['pork',
#   'poultry',
#   'all- purpose',
#   'sandwich bags',
#   'vegetables',
#   'individual meals',
#   'vegetables',
#   'laundry detergent',
#   'milk',
#   'soap',
#   'juice',
#   'aluminum foil',
#   'flour',
#   'individual meals'],
#  ['ice cream',
#   'all- purpose',
#   'hand soap',
#   'all- purpose',
#   'dishwashing liquid/detergent',
#   'paper towels',
#   'ketchup'],
#  ['ice cream',
#   'sandwich bags',
#   'individual meals',
#   'juice',
#   'fruits',
#   'cereals',
#   'pasta'],
#  ['milk',
#   'vegetables',
#   'coffee/tea',
#   'mixes',
#   'sandwich loaves',
#   'sandwich bags',
#   'waffles'],
#  ['mixes',
#   'coffee/tea',
#   'paper towels',
#   'dishwashing liquid/detergent',
#   'mixes'],
#  ['bagels',
#   'hand soap',
#   'dishwashing liquid/detergent',
#   'flour',
#   'individual meals',
#   'sandwich loaves',
#   'hand soap',
#   'vegetables',
#   'lunch meat',
#   'cheeses',
#   'milk',
#   'bagels',
#   'butter',
#   'soap'],
#  ['paper towels',
#   'sandwich loaves',
#   'yogurt',
#   'flour',
#   'lunch meat',
#   'sugar',
#   'laundry detergent',
#   'pork'],
#  ['sandwich loaves',
#   'aluminum foil',
#   'lunch meat',
#   'toilet paper',
#   'waffles',
#   'pasta',
#   'waffles',
#   'hand soap',
#   'tortillas',
#   'pork',
#   'butter',
#   'hand soap',
#   'laundry detergent',
#   'milk'],
#  ['fruits',
#   'fruits',
#   'ice cream',
#   'dishwashing liquid/detergent',
#   'yogurt',
#   'soda',
#   'dinner rolls',
#   'coffee/tea',
#   'vegetables',
#   'beef',
#   'bagels',
#   'toilet paper',
#   'beef',
#   'all- purpose'],
#  ['vegetables',
#   'cereals',
#   'dishwashing liquid/detergent',
#   'cereals',
#   'vegetables',
#   'sugar',
#   'cereals'],
#  ['laundry detergent',
#   'poultry',
#   'spaghetti sauce',
#   'vegetables',
#   'mixes',
#   'coffee/tea'],
#  ['laundry detergent',
#   'cheeses',
#   'shampoo',
#   'laundry detergent',
#   'hand soap',
#   'fruits',
#   'fruits',
#   'fruits',
#   'dinner rolls',
#   'soap',
#   'pork',
#   'cheeses',
#   'vegetables',
#   'sandwich bags'],
#  ['dishwashing liquid/detergent',
#   'bagels',
#   'laundry detergent',
#   'dinner rolls',
#   'cheeses',
#   'juice',
#   'sandwich bags',
#   'dinner rolls',
#   'fruits',
#   'yogurt',
#   'paper towels',
#   'lunch meat',
#   'aluminum foil',
#   'paper towels'],
#  ['individual meals',
#   'flour',
#   'spaghetti sauce',
#   'dishwashing liquid/detergent',
#   'sandwich bags',
#   'eggs',
#   'ketchup',
#   'pasta',
#   'vegetables',
#   'fruits',
#   'soda',
#   'hand soap',
#   'spaghetti sauce',
#   'sandwich bags'],
#  ['mixes',
#   'ketchup',
#   'spaghetti sauce',
#   'juice',
#   'individual meals',
#   'sugar',
#   'cereals',
#   'individual meals',
#   'all- purpose',
#   'dishwashing liquid/detergent',
#   'shampoo',
#   'butter',
#   'paper towels',
#   'flour'],
#  ['aluminum foil',
#   'butter',
#   'pork',
#   'coffee/tea',
#   'vegetables',
#   'juice',
#   'eggs',
#   'sandwich loaves'],
#  ['aluminum foil', 'shampoo', 'ketchup', 'tortillas'],
#  ['eggs',
#   'milk',
#   'paper towels',
#   'sugar',
#   'yogurt',
#   'pork',
#   'pork',
#   'individual meals',
#   'spaghetti sauce',
#   'cereals',
#   'spaghetti sauce',
#   'cheeses',
#   'flour',
#   'spaghetti sauce'],
#  ['tortillas', 'milk', 'flour', 'vegetables', 'paper towels', 'cereals'],
#  ['cheeses',
#   'flour',
#   'hand soap',
#   'vegetables',
#   'vegetables',
#   'sugar',
#   'flour',
#   'individual meals',
#   'tortillas',
#   'aluminum foil',
#   'fruits',
#   'waffles',
#   'all- purpose',
#   'vegetables'],
#  ['coffee/tea',
#   'vegetables',
#   'sandwich loaves',
#   'tortillas',
#   'tortillas',
#   'sandwich bags',
#   'soda',
#   'vegetables',
#   'waffles',
#   'ice cream',
#   'milk',
#   'beef',
#   'mixes',
#   'toilet paper'],
#  ['sandwich bags',
#   'aluminum foil',
#   'sandwich loaves',
#   'butter',
#   'coffee/tea',
#   'coffee/tea',
#   'tortillas',
#   'poultry',
#   'flour',
#   'soda',
#   'milk',
#   'paper towels',
#   'vegetables',
#   'ice cream'],
#  ['sugar',
#   'cheeses',
#   'beef',
#   'spaghetti sauce',
#   'lunch meat',
#   'soap',
#   'vegetables',
#   'paper towels',
#   'aluminum foil',
#   'toilet paper',
#   'dinner rolls',
#   'eggs',
#   'pasta',
#   'hand soap'],
#  ['toilet paper',
#   'soap',
#   'soda',
#   'cereals',
#   'vegetables',
#   'shampoo',
#   'yogurt',
#   'sugar',
#   'cereals',
#   'poultry',
#   'lunch meat',
#   'waffles',
#   'ice cream',
#   'sandwich loaves'],
#  ['flour',
#   'flour',
#   'individual meals',
#   'hand soap',
#   'dishwashing liquid/detergent',
#   'aluminum foil',
#   'cheeses',
#   'vegetables'],
#  ['laundry detergent',
#   'ketchup',
#   'ketchup',
#   'sugar',
#   'soap',
#   'lunch meat',
#   'vegetables',
#   'pork',
#   'lunch meat'],
#  ['yogurt', 'mixes', 'ketchup', 'eggs'],
#  ['cheeses',
#   'individual meals',
#   'pork',
#   'butter',
#   'eggs',
#   'fruits',
#   'laundry detergent',
#   'dishwashing liquid/detergent',
#   'soda',
#   'mixes',
#   'pasta',
#   'toilet paper',
#   'spaghetti sauce',
#   'dinner rolls'],
#  ['sandwich bags',
#   'bagels',
#   'spaghetti sauce',
#   'hand soap',
#   'laundry detergent',
#   'sugar',
#   'spaghetti sauce',
#   'dishwashing liquid/detergent',
#   'poultry',
#   'individual meals',
#   'yogurt'],
#  ['ice cream',
#   'coffee/tea',
#   'paper towels',
#   'vegetables',
#   'toilet paper',
#   'soda',
#   'beef',
#   'ketchup',
#   'ice cream',
#   'pork',
#   'individual meals',
#   'ketchup',
#   'fruits',
#   'vegetables'],
#  ['paper towels', 'butter', 'coffee/tea', 'sandwich bags'],
#  ['cheeses',
#   'soap',
#   'bagels',
#   'all- purpose',
#   'soap',
#   'bagels',
#   'mixes',
#   'sandwich loaves',
#   'butter',
#   'individual meals',
#   'soda',
#   'laundry detergent',
#   'sandwich loaves',
#   'eggs'],
#  ['bagels',
#   'soda',
#   'ketchup',
#   'fruits',
#   'pork',
#   'fruits',
#   'vegetables',
#   'ice cream',
#   'cereals',
#   'lunch meat',
#   'waffles',
#   'vegetables',
#   'ice cream',
#   'hand soap'],
#  ['hand soap',
#   'tortillas',
#   'dinner rolls',
#   'eggs',
#   'cereals',
#   'soda',
#   'soda',
#   'all- purpose',
#   'eggs',
#   'ice cream',
#   'waffles',
#   'hand soap',
#   'cheeses',
#   'poultry'],
#  ['tortillas',
#   'hand soap',
#   'ice cream',
#   'bagels',
#   'cereals',
#   'shampoo',
#   'vegetables',
#   'sandwich loaves',
#   'eggs',
#   'individual meals',
#   'paper towels',
#   'soap',
#   'butter',
#   'ketchup'],
#  ['bagels',
#   'poultry',
#   'ice cream',
#   'aluminum foil',
#   'spaghetti sauce',
#   'vegetables',
#   'pasta',
#   'pasta',
#   'paper towels',
#   'poultry',
#   'all- purpose',
#   'hand soap',
#   'fruits',
#   'soda'],
#  ['tortillas',
#   'coffee/tea',
#   'poultry',
#   'lunch meat',
#   'butter',
#   'mixes',
#   'laundry detergent',
#   'paper towels',
#   'milk',
#   'vegetables',
#   'vegetables',
#   'dinner rolls',
#   'fruits',
#   'dishwashing liquid/detergent'],
#  ['juice',
#   'pork',
#   'sandwich bags',
#   'aluminum foil',
#   'toilet paper',
#   'dinner rolls',
#   'ketchup',
#   'milk',
#   'flour',
#   'fruits',
#   'hand soap',
#   'ice cream',
#   'coffee/tea',
#   'mixes'],
#  ['laundry detergent',
#   'paper towels',
#   'sugar',
#   'pasta',
#   'laundry detergent',
#   'soda',
#   'tortillas',
#   'laundry detergent',
#   'coffee/tea',
#   'all- purpose',
#   'soda',
#   'eggs',
#   'ketchup',
#   'ketchup'],
#  ['toilet paper',
#   'hand soap',
#   'coffee/tea',
#   'fruits',
#   'flour',
#   'laundry detergent',
#   'bagels'],
#  ['bagels', 'fruits', 'laundry detergent', 'toilet paper'],
#  ['poultry',
#   'shampoo',
#   'hand soap',
#   'cereals',
#   'butter',
#   'dinner rolls',
#   'cereals',
#   'tortillas',
#   'yogurt',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'soda',
#   'fruits',
#   'soda'],
#  ['dinner rolls',
#   'bagels',
#   'vegetables',
#   'soap',
#   'soap',
#   'spaghetti sauce',
#   'mixes',
#   'soda',
#   'juice',
#   'pasta',
#   'mixes',
#   'paper towels',
#   'soda',
#   'individual meals'],
#  ['butter',
#   'vegetables',
#   'aluminum foil',
#   'individual meals',
#   'poultry',
#   'hand soap',
#   'sugar',
#   'soda',
#   'soda',
#   'vegetables',
#   'laundry detergent',
#   'vegetables',
#   'flour',
#   'eggs'],
#  ['ice cream',
#   'waffles',
#   'shampoo',
#   'dinner rolls',
#   'yogurt',
#   'cereals',
#   'aluminum foil',
#   'mixes',
#   'spaghetti sauce',
#   'waffles',
#   'coffee/tea',
#   'vegetables',
#   'cereals',
#   'poultry'],
#  ['pasta',
#   'ice cream',
#   'pork',
#   'dishwashing liquid/detergent',
#   'ice cream',
#   'paper towels',
#   'ice cream',
#   'lunch meat',
#   'paper towels',
#   'waffles',
#   'tortillas',
#   'milk',
#   'butter',
#   'vegetables'],
#  ['tortillas',
#   'aluminum foil',
#   'yogurt',
#   'individual meals',
#   'lunch meat',
#   'waffles',
#   'toilet paper',
#   'poultry',
#   'sandwich loaves',
#   'aluminum foil',
#   'milk',
#   'dinner rolls',
#   'individual meals',
#   'flour'],
#  ['vegetables',
#   'vegetables',
#   'paper towels',
#   'lunch meat',
#   'waffles',
#   'paper towels',
#   'butter',
#   'vegetables',
#   'butter',
#   'tortillas',
#   'ice cream',
#   'spaghetti sauce',
#   'waffles'],
#  ['cereals',
#   'shampoo',
#   'soda',
#   'yogurt',
#   'sugar',
#   'sandwich bags',
#   'lunch meat',
#   'sugar',
#   'yogurt',
#   'sugar',
#   'juice',
#   'pasta',
#   'shampoo',
#   'dinner rolls'],
#  ['waffles',
#   'hand soap',
#   'fruits',
#   'sugar',
#   'milk',
#   'bagels',
#   'dishwashing liquid/detergent',
#   'waffles',
#   'soda',
#   'ice cream',
#   'pasta',
#   'flour',
#   'butter',
#   'mixes'],
#  ['dishwashing liquid/detergent',
#   'aluminum foil',
#   'sandwich bags',
#   'poultry',
#   'flour',
#   'waffles'],
#  ['all- purpose',
#   'soap',
#   'individual meals',
#   'mixes',
#   'individual meals',
#   'cereals',
#   'bagels',
#   'beef',
#   'laundry detergent',
#   'vegetables',
#   'waffles',
#   'flour',
#   'cheeses',
#   'dishwashing liquid/detergent'],
#  ['soap',
#   'coffee/tea',
#   'pasta',
#   'sugar',
#   'aluminum foil',
#   'ice cream',
#   'eggs',
#   'dinner rolls',
#   'sugar',
#   'fruits',
#   'butter',
#   'milk',
#   'hand soap',
#   'aluminum foil'],
#  ['sandwich loaves', 'paper towels', 'sugar', 'mixes'],
#  ['butter',
#   'dishwashing liquid/detergent',
#   'laundry detergent',
#   'spaghetti sauce',
#   'sandwich loaves',
#   'pork',
#   'spaghetti sauce',
#   'toilet paper',
#   'milk',
#   'vegetables',
#   'laundry detergent',
#   'aluminum foil',
#   'aluminum foil',
#   'beef'],
#  ['vegetables', 'eggs', 'eggs', 'waffles'],
#  ['cereals',
#   'sandwich loaves',
#   'paper towels',
#   'ice cream',
#   'beef',
#   'coffee/tea',
#   'vegetables',
#   'sandwich bags',
#   'fruits',
#   'ice cream',
#   'eggs',
#   'pasta',
#   'toilet paper',
#   'waffles'],
#  ['cheeses',
#   'butter',
#   'individual meals',
#   'vegetables',
#   'poultry',
#   'soap',
#   'vegetables',
#   'toilet paper',
#   'fruits',
#   'dinner rolls',
#   'vegetables',
#   'tortillas',
#   'butter',
#   'dinner rolls'],
#  ['waffles',
#   'waffles',
#   'toilet paper',
#   'tortillas',
#   'fruits',
#   'hand soap',
#   'all- purpose',
#   'flour',
#   'all- purpose',
#   'tortillas',
#   'mixes',
#   'soda',
#   'mixes',
#   'shampoo'],
#  ['dinner rolls',
#   'juice',
#   'aluminum foil',
#   'paper towels',
#   'hand soap',
#   'ice cream',
#   'vegetables',
#   'vegetables',
#   'aluminum foil',
#   'tortillas',
#   'soda',
#   'bagels',
#   'vegetables',
#   'vegetables'],
#  ['dishwashing liquid/detergent',
#   'all- purpose',
#   'bagels',
#   'aluminum foil',
#   'vegetables',
#   'ketchup',
#   'pasta',
#   'dishwashing liquid/detergent',
#   'lunch meat',
#   'ice cream',
#   'shampoo',
#   'sugar',
#   'fruits',
#   'fruits'],
#  ['beef', 'yogurt', 'butter', 'yogurt', 'waffles', 'waffles'],
#  ['dishwashing liquid/detergent',
#   'dishwashing liquid/detergent',
#   'beef',
#   'soda',
#   'coffee/tea',
#   'ketchup',
#   'mixes',
#   'all- purpose',
#   'flour',
#   'fruits',
#   'vegetables',
#   'sandwich bags',
#   'vegetables',
#   'fruits'],
#  ['vegetables', 'cereals', 'ketchup', 'bagels', 'ice cream'],
#  ['tortillas',
#   'spaghetti sauce',
#   'laundry detergent',
#   'aluminum foil',
#   'spaghetti sauce',
#   'yogurt',
#   'sandwich bags',
#   'poultry',
#   'ketchup',
#   'fruits',
#   'yogurt',
#   'butter',
#   'all- purpose',
#   'butter'],
#  ['soda',
#   'toilet paper',
#   'individual meals',
#   'aluminum foil',
#   'poultry',
#   'dinner rolls',
#   'waffles',
#   'soap',
#   'cheeses',
#   'eggs',
#   'cheeses',
#   'juice',
#   'pasta',
#   'vegetables'],
#  ['spaghetti sauce',
#   'coffee/tea',
#   'mixes',
#   'milk',
#   'vegetables',
#   'sugar',
#   'tortillas',
#   'juice',
#   'coffee/tea',
#   'mixes',
#   'ketchup',
#   'eggs',
#   'pasta',
#   'vegetables'],
#  ['butter',
#   'butter',
#   'aluminum foil',
#   'aluminum foil',
#   'sandwich loaves',
#   'toilet paper',
#   'poultry',
#   'aluminum foil',
#   'vegetables',
#   'pasta',
#   'butter',
#   'coffee/tea',
#   'pasta',
#   'yogurt'],
#  ['vegetables',
#   'eggs',
#   'vegetables',
#   'laundry detergent',
#   'cereals',
#   'all- purpose'],
#  ['poultry',
#   'waffles',
#   'tortillas',
#   'aluminum foil',
#   'flour',
#   'beef',
#   'yogurt',
#   'waffles',
#   'all- purpose',
#   'vegetables',
#   'flour',
#   'tortillas',
#   'butter',
#   'individual meals'],
#  ['ice cream',
#   'bagels',
#   'waffles',
#   'ice cream',
#   'dishwashing liquid/detergent',
#   'sandwich bags',
#   'sugar',
#   'cheeses',
#   'spaghetti sauce',
#   'flour',
#   'pasta',
#   'pasta',
#   'eggs',
#   'paper towels'],
#  ['poultry',
#   'bagels',
#   'coffee/tea',
#   'all- purpose',
#   'sandwich loaves',
#   'spaghetti sauce',
#   'shampoo',
#   'mixes',
#   'sandwich loaves',
#   'soda',
#   'individual meals',
#   'dishwashing liquid/detergent',
#   'dinner rolls',
#   'laundry detergent'],
#  ['sandwich loaves',
#   'sugar',
#   'fruits',
#   'eggs',
#   'cheeses',
#   'spaghetti sauce',
#   'waffles'],
#  ['dinner rolls',
#   'cheeses',
#   'laundry detergent',
#   'all- purpose',
#   'pasta',
#   'aluminum foil',
#   'fruits',
#   'ketchup',
#   'fruits',
#   'butter',
#   'ice cream',
#   'paper towels',
#   'fruits',
#   'sugar'],
#  ['cereals',
#   'eggs',
#   'hand soap',
#   'vegetables',
#   'butter',
#   'soda',
#   'yogurt',
#   'shampoo',
#   'bagels',
#   'pasta',
#   'tortillas',
#   'sugar',
#   'fruits',
#   'toilet paper'],
#  ['sandwich loaves',
#   'lunch meat',
#   'soda',
#   'cheeses',
#   'mixes',
#   'bagels',
#   'soap',
#   'vegetables',
#   'cereals',
#   'yogurt',
#   'hand soap',
#   'juice',
#   'sugar',
#   'butter'],
#  ['vegetables',
#   'paper towels',
#   'spaghetti sauce',
#   'butter',
#   'fruits',
#   'cheeses',
#   'poultry',
#   'pasta',
#   'vegetables',
#   'mixes',
#   'spaghetti sauce',
#   'aluminum foil',
#   'coffee/tea',
#   'spaghetti sauce'],
#  ['cereals',
#   'cheeses',
#   'paper towels',
#   'tortillas',
#   'flour',
#   'sandwich loaves',
#   'all- purpose'],
#  ['toilet paper',
#   'sandwich loaves',
#   'spaghetti sauce',
#   'poultry',
#   'pasta',
#   'waffles',
#   'butter',
#   'dinner rolls',
#   'flour',
#   'fruits',
#   'all- purpose',
#   'bagels',
#   'toilet paper',
#   'lunch meat'],
#  ['sugar',
#   'poultry',
#   'juice',
#   'paper towels',
#   'eggs',
#   'juice',
#   'bagels',
#   'hand soap',
#   'mixes',
#   'paper towels',
#   'hand soap',
#   'tortillas',
#   'vegetables',
#   'dinner rolls'],
#  ['cereals',
#   'shampoo',
#   'dishwashing liquid/detergent',
#   'individual meals',
#   'fruits',
#   'poultry',
#   'beef',
#   'vegetables',
#   'yogurt',
#   'waffles',
#   'toilet paper',
#   'juice',
#   'individual meals',
#   'vegetables'],
#  ['lunch meat',
#   'butter',
#   'cereals',
#   'fruits',
#   'fruits',
#   'tortillas',
#   'waffles',
#   'hand soap'],
#  ['flour',
#   'beef',
#   'coffee/tea',
#   'sandwich bags',
#   'poultry',
#   'poultry',
#   'eggs',
#   'yogurt',
#   'mixes',
#   'yogurt',
#   'all- purpose',
#   'flour',
#   'spaghetti sauce',
#   'individual meals'],
#  ['all- purpose',
#   'sandwich bags',
#   'fruits',
#   'waffles',
#   'cheeses',
#   'sandwich loaves',
#   'vegetables',
#   'lunch meat',
#   'soda',
#   'dinner rolls',
#   'all- purpose',
#   'pasta',
#   'beef',
#   'hand soap'],
#  ['laundry detergent',
#   'mixes',
#   'pasta',
#   'pasta',
#   'mixes',
#   'laundry detergent',
#   'soda',
#   'bagels',
#   'soda',
#   'spaghetti sauce',
#   'butter',
#   'shampoo',
#   'toilet paper',
#   'sandwich loaves'],
#  ['bagels',
#   'milk',
#   'fruits',
#   'paper towels',
#   'soap',
#   'dinner rolls',
#   'all- purpose',
#   'flour',
#   'lunch meat',
#   'sugar',
#   'pork',
#   'sandwich loaves',
#   'laundry detergent',
#   'shampoo'],
#  ['eggs', 'shampoo', 'aluminum foil', 'milk', 'waffles', 'ketchup'],
#  ['sandwich bags',
#   'spaghetti sauce',
#   'all- purpose',
#   'aluminum foil',
#   'milk',
#   'bagels',
#   'toilet paper',
#   'eggs',
#   'coffee/tea',
#   'toilet paper',
#   'mixes',
#   'toilet paper',
#   'paper towels',
#   'mixes'],
#  ['fruits', 'dishwashing liquid/detergent', 'paper towels', 'pasta', 'waffles'],
#  ['laundry detergent',
#   'vegetables',
#   'soap',
#   'shampoo',
#   'milk',
#   'eggs',
#   'paper towels'],
#  ['toilet paper',
#   'lunch meat',
#   'aluminum foil',
#   'lunch meat',
#   'laundry detergent',
#   'toilet paper',
#   'vegetables',
#   'vegetables',
#   'all- purpose',
#   'bagels',
#   'pasta'],
#  ['vegetables',
#   'juice',
#   'sandwich bags',
#   'shampoo',
# ...
#   'toilet paper',
#   'yogurt',
#   'individual meals',
#   'beef'],
#  ['aluminum foil',
#   'dinner rolls',
#   'sandwich loaves',
#   'butter',
#   'tortillas',
#   'vegetables',
#   'hand soap',
#   'dinner rolls',
#   'vegetables'],
#  ['paper towels',
#   'eggs',
#   'lunch meat',
#   'sandwich loaves',
#   'butter',
#   'dishwashing liquid/detergent',
#   'juice',
#   'laundry detergent',
#   'fruits',
#   'vegetables',
#   'dishwashing liquid/detergent',
#   'butter',
#   'poultry',
#   'bagels'],
#  ['tortillas',
#   'vegetables',
#   'pasta',
#   'soap',
#   'dishwashing liquid/detergent',
#   'mixes',
#   'tortillas',
#   'fruits',
#   'milk',
#   'soda',
#   'dinner rolls',
#   'vegetables',
#   'dinner rolls',
#   'cereals'],
#  ['dishwashing liquid/detergent',
#   'coffee/tea',
#   'vegetables',
#   'bagels',
#   'sandwich bags',
#   'milk',
#   'tortillas',
#   'yogurt',
#   'beef',
#   'hand soap'],
#  ['dinner rolls', 'poultry', 'aluminum foil', 'juice'],
#  ['flour',
#   'soda',
#   'ice cream',
#   'lunch meat',
#   'juice',
#   'ketchup',
#   'flour',
#   'beef',
#   'all- purpose',
#   'butter',
#   'laundry detergent',
#   'vegetables',
#   'butter',
#   'individual meals'],
#  ['eggs',
#   'juice',
#   'dinner rolls',
#   'vegetables',
#   'yogurt',
#   'spaghetti sauce',
#   'beef',
#   'vegetables',
#   'paper towels',
#   'shampoo',
#   'dinner rolls',
#   'beef',
#   'aluminum foil',
#   'soda'],
#  ['shampoo',
#   'soda',
#   'eggs',
#   'paper towels',
#   'flour',
#   'paper towels',
#   'shampoo',
#   'pasta',
#   'soda',
#   'eggs',
#   'ketchup',
#   'toilet paper',
#   'individual meals',
#   'yogurt'],
#  ['eggs',
#   'beef',
#   'ketchup',
#   'pork',
#   'dinner rolls',
#   'bagels',
#   'coffee/tea',
#   'tortillas',
#   'spaghetti sauce',
#   'pasta',
#   'waffles',
#   'all- purpose',
#   'milk',
#   'coffee/tea'],
#  ['sandwich bags',
#   'soda',
#   'tortillas',
#   'soda',
#   'tortillas',
#   'eggs',
#   'pasta',
#   'soda',
#   'yogurt',
#   'shampoo',
#   'lunch meat',
#   'milk',
#   'laundry detergent',
#   'cheeses'],
#  ['sugar',
#   'poultry',
#   'sandwich loaves',
#   'cereals',
#   'poultry',
#   'tortillas',
#   'vegetables',
#   'tortillas',
#   'vegetables',
#   'vegetables',
#   'ice cream',
#   'lunch meat',
#   'eggs',
#   'butter'],
#  ['poultry',
#   'sandwich loaves',
#   'dinner rolls',
#   'pork',
#   'coffee/tea',
#   'hand soap',
#   'cheeses',
#   'dinner rolls',
#   'all- purpose',
#   'butter',
#   'ketchup',
#   'laundry detergent',
#   'spaghetti sauce',
#   'cheeses'],
#  ['individual meals',
#   'pork',
#   'individual meals',
#   'individual meals',
#   'soap',
#   'paper towels',
#   'sandwich loaves',
#   'eggs',
#   'cereals',
#   'aluminum foil',
#   'dinner rolls',
#   'ice cream',
#   'soap',
#   'shampoo'],
#  ['sandwich bags',
#   'pasta',
#   'milk',
#   'milk',
#   'dishwashing liquid/detergent',
#   'all- purpose',
#   'individual meals',
#   'shampoo',
#   'pork',
#   'juice',
#   'pasta',
#   'paper towels'],
#  ['soap',
#   'hand soap',
#   'all- purpose',
#   'sugar',
#   'vegetables',
#   'yogurt',
#   'poultry',
#   'hand soap',
#   'flour',
#   'waffles',
#   'pork',
#   'spaghetti sauce',
#   'butter',
#   'shampoo'],
#  ['soap',
#   'flour',
#   'dishwashing liquid/detergent',
#   'lunch meat',
#   'milk',
#   'poultry'],
#  ['all- purpose',
#   'tortillas',
#   'yogurt',
#   'all- purpose',
#   'ketchup',
#   'vegetables',
#   'butter',
#   'dinner rolls',
#   'flour',
#   'butter',
#   'ketchup',
#   'mixes',
#   'laundry detergent',
#   'milk'],
#  ['poultry', 'coffee/tea', 'sandwich loaves', 'individual meals'],
#  ['aluminum foil',
#   'dishwashing liquid/detergent',
#   'spaghetti sauce',
#   'paper towels',
#   'soda',
#   'ketchup',
#   'dinner rolls',
#   'soap',
#   'ketchup',
#   'milk',
#   'milk',
#   'ice cream',
#   'flour',
#   'juice'],
#  ['vegetables',
#   'sandwich bags',
#   'vegetables',
#   'soda',
#   'coffee/tea',
#   'sandwich loaves',
#   'hand soap'],
#  ['lunch meat',
#   'eggs',
#   'eggs',
#   'individual meals',
#   'all- purpose',
#   'beef',
#   'spaghetti sauce',
#   'vegetables',
#   'paper towels',
#   'eggs',
#   'cereals',
#   'individual meals',
#   'fruits',
#   'dishwashing liquid/detergent'],
#  ['tortillas',
#   'bagels',
#   'all- purpose',
#   'spaghetti sauce',
#   'juice',
#   'sugar',
#   'paper towels',
#   'fruits',
#   'fruits',
#   'individual meals',
#   'eggs',
#   'spaghetti sauce',
#   'pork',
#   'pork'],
#  ['individual meals',
#   'beef',
#   'milk',
#   'laundry detergent',
#   'hand soap',
#   'bagels',
#   'milk',
#   'vegetables',
#   'aluminum foil',
#   'vegetables',
#   'toilet paper',
#   'aluminum foil',
#   'soda',
#   'vegetables'],
#  ['fruits',
#   'yogurt',
#   'sugar',
#   'cheeses',
#   'pasta',
#   'soda',
#   'butter',
#   'vegetables',
#   'butter',
#   'dishwashing liquid/detergent',
#   'cheeses',
#   'ice cream',
#   'pork',
#   'ice cream'],
#  ['dishwashing liquid/detergent',
#   'flour',
#   'paper towels',
#   'yogurt',
#   'flour',
#   'spaghetti sauce',
#   'fruits',
#   'ice cream',
#   'vegetables',
#   'cheeses',
#   'all- purpose',
#   'pork',
#   'cheeses',
#   'yogurt'],
#  ['all- purpose',
#   'ice cream',
#   'dishwashing liquid/detergent',
#   'sandwich loaves',
#   'butter'],
#  ['vegetables',
#   'milk',
#   'ketchup',
#   'juice',
#   'toilet paper',
#   'hand soap',
#   'shampoo',
#   'bagels',
#   'sandwich bags',
#   'coffee/tea',
#   'fruits',
#   'eggs',
#   'mixes',
#   'cereals'],
#  ['dinner rolls',
#   'shampoo',
#   'vegetables',
#   'eggs',
#   'coffee/tea',
#   'ice cream',
#   'sandwich bags',
#   'pasta',
#   'milk',
#   'tortillas'],
#  ['pork',
#   'individual meals',
#   'lunch meat',
#   'mixes',
#   'beef',
#   'vegetables',
#   'coffee/tea',
#   'cereals',
#   'dishwashing liquid/detergent',
#   'aluminum foil',
#   'coffee/tea',
#   'soda'],
#  ['lunch meat',
#   'flour',
#   'pasta',
#   'dinner rolls',
#   'soda',
#   'toilet paper',
#   'vegetables',
#   'aluminum foil',
#   'yogurt',
#   'toilet paper',
#   'paper towels',
#   'coffee/tea',
#   'ice cream',
#   'individual meals'],
#  ['dinner rolls',
#   'spaghetti sauce',
#   'soda',
#   'butter',
#   'paper towels',
#   'poultry',
#   'pasta',
#   'dishwashing liquid/detergent',
#   'fruits',
#   'poultry',
#   'vegetables',
#   'butter',
#   'mixes',
#   'flour'],
#  ['juice',
#   'milk',
#   'paper towels',
#   'bagels',
#   'dinner rolls',
#   'soda',
#   'vegetables',
#   'pork',
#   'toilet paper',
#   'pasta',
#   'ketchup',
#   'soda',
#   'fruits',
#   'cereals'],
#  ['coffee/tea',
#   'dishwashing liquid/detergent',
#   'waffles',
#   'ketchup',
#   'vegetables',
#   'flour',
#   'dinner rolls',
#   'shampoo',
#   'shampoo',
#   'dishwashing liquid/detergent',
#   'poultry',
#   'paper towels'],
#  ['mixes',
#   'fruits',
#   'pork',
#   'dinner rolls',
#   'butter',
#   'all- purpose',
#   'pasta',
#   'soda',
#   'pasta',
#   'sandwich loaves',
#   'eggs',
#   'mixes',
#   'vegetables',
#   'eggs'],
#  ['ice cream', 'dinner rolls', 'coffee/tea', 'coffee/tea', 'bagels', 'pork'],
#  ['individual meals',
#   'fruits',
#   'toilet paper',
#   'cereals',
#   'individual meals',
#   'dishwashing liquid/detergent',
#   'mixes',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'ketchup',
#   'poultry',
#   'aluminum foil',
#   'butter',
#   'dishwashing liquid/detergent'],
#  ['individual meals',
#   'sandwich bags',
#   'cereals',
#   'yogurt',
#   'soda',
#   'laundry detergent',
#   'bagels',
#   'laundry detergent',
#   'vegetables',
#   'vegetables',
#   'flour',
#   'cereals',
#   'spaghetti sauce',
#   'cheeses'],
#  ['dinner rolls',
#   'soda',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'individual meals',
#   'fruits',
#   'laundry detergent',
#   'ice cream',
#   'juice',
#   'beef',
#   'ketchup',
#   'bagels',
#   'paper towels',
#   'toilet paper'],
#  ['vegetables',
#   'ice cream',
#   'individual meals',
#   'pork',
#   'mixes',
#   'soap',
#   'ice cream',
#   'ketchup',
#   'mixes',
#   'individual meals',
#   'poultry',
#   'paper towels',
#   'vegetables',
#   'cheeses'],
#  ['poultry', 'vegetables', 'waffles', 'all- purpose', 'yogurt'],
#  ['eggs',
#   'laundry detergent',
#   'sugar',
#   'flour',
#   'sandwich loaves',
#   'yogurt',
#   'lunch meat',
#   'vegetables',
#   'spaghetti sauce',
#   'beef',
#   'cereals',
#   'flour',
#   'cereals',
#   'poultry'],
#  ['cheeses', 'vegetables', 'flour', 'soap', 'ice cream'],
#  ['mixes',
#   'toilet paper',
#   'sandwich loaves',
#   'coffee/tea',
#   'vegetables',
#   'flour',
#   'soap',
#   'vegetables',
#   'beef',
#   'sugar',
#   'ice cream',
#   'cereals',
#   'tortillas',
#   'juice'],
#  ['dishwashing liquid/detergent',
#   'toilet paper',
#   'toilet paper',
#   'mixes',
#   'yogurt',
#   'individual meals',
#   'dinner rolls',
#   'paper towels',
#   'sugar',
#   'tortillas',
#   'laundry detergent',
#   'vegetables',
#   'all- purpose',
#   'soda'],
#  ['cereals',
#   'sandwich loaves',
#   'soda',
#   'toilet paper',
#   'shampoo',
#   'pasta',
#   'beef',
#   'pasta',
#   'sandwich loaves',
#   'ice cream',
#   'cereals',
#   'dinner rolls',
#   'beef',
#   'cereals'],
#  ['ketchup',
#   'vegetables',
#   'juice',
#   'ketchup',
#   'soap',
#   'cheeses',
#   'shampoo',
#   'tortillas',
#   'lunch meat',
#   'waffles',
#   'flour',
#   'tortillas',
#   'ice cream',
#   'individual meals'],
#  ['soap',
#   'all- purpose',
#   'lunch meat',
#   'vegetables',
#   'beef',
#   'dinner rolls',
#   'mixes',
#   'sandwich loaves',
#   'poultry',
#   'fruits',
#   'pork',
#   'lunch meat',
#   'paper towels',
#   'soda'],
#  ['aluminum foil',
#   'all- purpose',
#   'sandwich bags',
#   'pork',
#   'bagels',
#   'sugar',
#   'pork',
#   'coffee/tea',
#   'vegetables',
#   'lunch meat',
#   'ketchup'],
#  ['shampoo',
#   'pasta',
#   'flour',
#   'cereals',
#   'mixes',
#   'dishwashing liquid/detergent',
#   'aluminum foil',
#   'dishwashing liquid/detergent',
#   'tortillas',
#   'yogurt',
#   'flour',
#   'individual meals',
#   'laundry detergent',
#   'all- purpose'],
#  ['ketchup',
#   'paper towels',
#   'sandwich bags',
#   'pasta',
#   'laundry detergent',
#   'paper towels',
#   'butter',
#   'beef',
#   'waffles',
#   'tortillas',
#   'coffee/tea',
#   'waffles',
#   'poultry',
#   'juice'],
#  ['dinner rolls',
#   'bagels',
#   'waffles',
#   'sandwich loaves',
#   'pasta',
#   'individual meals',
#   'milk',
#   'soap',
#   'laundry detergent',
#   'spaghetti sauce',
#   'shampoo',
#   'dinner rolls',
#   'cheeses',
#   'laundry detergent'],
#  ['sandwich bags',
#   'flour',
#   'waffles',
#   'vegetables',
#   'ice cream',
#   'yogurt',
#   'tortillas',
#   'hand soap',
#   'paper towels'],
#  ['dinner rolls',
#   'ice cream',
#   'butter',
#   'sandwich loaves',
#   'shampoo',
#   'beef',
#   'eggs',
#   'butter',
#   'beef',
#   'waffles',
#   'aluminum foil',
#   'ketchup',
#   'eggs',
#   'sandwich loaves'],
#  ['dishwashing liquid/detergent',
#   'bagels',
#   'aluminum foil',
#   'hand soap',
#   'aluminum foil',
#   'laundry detergent'],
#  ['vegetables',
#   'fruits',
#   'cereals',
#   'milk',
#   'vegetables',
#   'yogurt',
#   'vegetables',
#   'eggs',
#   'hand soap',
#   'all- purpose',
#   'bagels'],
#  ['milk',
#   'toilet paper',
#   'individual meals',
#   'shampoo',
#   'vegetables',
#   'cheeses',
#   'hand soap'],
#  ['soap',
#   'ice cream',
#   'butter',
#   'vegetables',
#   'dinner rolls',
#   'mixes',
#   'lunch meat',
#   'waffles',
#   'hand soap'],
#  ['poultry',
#   'soap',
#   'mixes',
#   'fruits',
#   'dishwashing liquid/detergent',
#   'vegetables',
#   'eggs',
#   'ice cream',
#   'tortillas',
#   'sugar',
#   'lunch meat',
#   'tortillas',
#   'mixes',
#   'lunch meat'],
#  ['tortillas',
#   'mixes',
#   'cheeses',
#   'toilet paper',
#   'juice',
#   'mixes',
#   'toilet paper',
#   'beef',
#   'aluminum foil',
#   'yogurt',
#   'sandwich bags',
#   'sugar',
#   'cheeses',
#   'lunch meat'],
#  ['all- purpose',
#   'sandwich loaves',
#   'pork',
#   'bagels',
#   'sugar',
#   'juice',
#   'flour',
#   'waffles',
#   'sandwich loaves',
#   'sandwich loaves',
#   'sandwich bags',
#   'juice',
#   'flour',
#   'fruits'],
#  ['mixes',
#   'sandwich bags',
#   'all- purpose',
#   'dinner rolls',
#   'soda',
#   'vegetables',
#   'pork',
#   'butter',
#   'lunch meat',
#   'toilet paper',
#   'ice cream',
#   'dishwashing liquid/detergent',
#   'spaghetti sauce',
#   'dinner rolls'],
#  ['ketchup', 'spaghetti sauce', 'cheeses', 'vegetables'],
#  ['aluminum foil',
#   'butter',
#   'laundry detergent',
#   'spaghetti sauce',
#   'pasta',
#   'sandwich loaves',
#   'all- purpose',
#   'lunch meat',
#   'ketchup',
#   'bagels',
#   'ketchup',
#   'pork',
#   'toilet paper',
#   'sandwich loaves'],
#  ['flour',
#   'paper towels',
#   'cereals',
#   'pork',
#   'pork',
#   'vegetables',
#   'fruits',
#   'coffee/tea',
#   'toilet paper',
#   'cheeses',
#   'sandwich bags',
#   'soap',
#   'cheeses',
#   'beef'],
#  ['butter',
#   'butter',
#   'flour',
#   'fruits',
#   'vegetables',
#   'all- purpose',
#   'mixes',
#   'pork',
#   'mixes',
#   'sandwich loaves',
#   'flour',
#   'vegetables',
#   'mixes',
#   'beef'],
#  ['sandwich loaves',
#   'flour',
#   'yogurt',
#   'all- purpose',
#   'sandwich loaves',
#   'cereals',
#   'soap',
#   'toilet paper',
#   'sandwich bags',
#   'all- purpose',
#   'poultry',
#   'juice',
#   'dinner rolls',
#   'all- purpose'],
#  ['cheeses',
#   'paper towels',
#   'vegetables',
#   'pasta',
#   'milk',
#   'cereals',
#   'poultry',
#   'cheeses',
#   'yogurt',
#   'coffee/tea',
#   'dinner rolls',
#   'soda',
#   'flour',
#   'all- purpose'],
#  ['beef',
#   'lunch meat',
#   'vegetables',
#   'vegetables',
#   'yogurt',
#   'ice cream',
#   'aluminum foil',
#   'poultry',
#   'individual meals',
#   'dinner rolls',
#   'pork',
#   'dinner rolls',
#   'vegetables',
#   'poultry'],
#  ['soap',
#   'cheeses',
#   'vegetables',
#   'beef',
#   'vegetables',
#   'toilet paper',
#   'shampoo',
#   'cereals',
#   'soda'],
#  ['individual meals',
#   'paper towels',
#   'aluminum foil',
#   'waffles',
#   'cheeses',
#   'vegetables',
#   'dinner rolls',
#   'laundry detergent',
#   'dinner rolls',
#   'vegetables',
#   'toilet paper',
#   'juice',
#   'cereals',
#   'shampoo'],
#  ['vegetables',
#   'vegetables',
#   'vegetables',
#   'vegetables',
#   'poultry',
#   'mixes',
#   'sandwich bags',
#   'vegetables',
#   'spaghetti sauce',
#   'juice',
#   'vegetables',
#   'yogurt',
#   'toilet paper',
#   'laundry detergent'],
#  ['toilet paper',
#   'lunch meat',
#   'laundry detergent',
#   'ketchup',
#   'individual meals',
#   'mixes',
#   'poultry',
#   'fruits',
#   'soda',
#   'soap',
#   'sugar',
#   'dishwashing liquid/detergent',
#   'beef',
#   'beef'],
#  ['soda', 'pasta', 'dinner rolls', 'cheeses'],
#  ['fruits',
#   'spaghetti sauce',
#   'mixes',
#   'vegetables',
#   'beef',
#   'lunch meat',
#   'dishwashing liquid/detergent',
#   'dishwashing liquid/detergent',
#   'waffles',
#   'poultry',
#   'laundry detergent',
#   'poultry',
#   'laundry detergent',
#   'lunch meat'],
#  ['spaghetti sauce',
#   'yogurt',
#   'sandwich loaves',
#   'poultry',
#   'mixes',
#   'ice cream',
#   'paper towels',
#   'sandwich loaves',
#   'cereals',
#   'yogurt',
#   'all- purpose',
#   'vegetables',
#   'cereals',
#   'pork'],
#  ['waffles',
#   'mixes',
#   'vegetables',
#   'individual meals',
#   'ice cream',
#   'tortillas',
#   'ice cream',
#   'mixes',
#   'poultry',
#   'yogurt',
#   'eggs',
#   'bagels',
#   'tortillas',
#   'coffee/tea'],
#  ['waffles',
#   'mixes',
#   'dinner rolls',
#   'vegetables',
#   'sandwich bags',
#   'ketchup',
#   'coffee/tea',
#   'cheeses',
#   'juice',
#   'yogurt',
#   'pasta',
#   'bagels',
#   'butter',
#   'sugar'],
#  ['sandwich bags',
#   'dishwashing liquid/detergent',
#   'toilet paper',
#   'juice',
#   'sandwich loaves',
#   'butter',
#   'sugar',
#   'vegetables',
#   'milk',
#   'butter',
#   'yogurt',
#   'laundry detergent',
#   'eggs',
#   'juice'],
#  ['laundry detergent',
#   'ice cream',
#   'eggs',
#   'bagels',
#   'dishwashing liquid/detergent',
#   'juice',
#   'pork',
#   'cheeses',
#   'pasta',
#   'soda',
#   'cheeses',
#   'milk'],
#  ['cheeses',
#   'poultry',
#   'dishwashing liquid/detergent',
#   'sandwich loaves',
#   'toilet paper',
#   'eggs',
#   'soap',
#   'vegetables',
#   'sandwich loaves',
#   'toilet paper',
#   'ketchup',
#   'toilet paper',
#   'laundry detergent',
#   'lunch meat'],
#  ['butter',
#   'hand soap',
#   'bagels',
#   'soap',
#   'laundry detergent',
#   'toilet paper',
#   'hand soap',
#   'fruits',
#   'ketchup',
#   'poultry',
#   'ice cream',
#   'juice',
#   'tortillas',
#   'ice cream'],
#  ['pasta', 'toilet paper', 'pork', 'cheeses', 'coffee/tea'],
#  ['beef',
#   'sandwich bags',
#   'hand soap',
#   'paper towels',
#   'paper towels',
#   'all- purpose',
#   'beef',
#   'fruits',
#   'coffee/tea',
#   'beef',
#   'shampoo',
#   'mixes',
#   'cheeses',
#   'juice'],
#  ['dinner rolls',
#   'lunch meat',
#   'spaghetti sauce',
#   'pasta',
#   'vegetables',
#   'cereals',
#   'dinner rolls',
#   'soap',
#   'milk',
#   'eggs',
#   'poultry',
#   'cheeses',
#   'cereals',
#   'mixes'],
#  ['lunch meat',
#   'eggs',
#   'poultry',
#   'vegetables',
#   'tortillas',
#   'beef',
#   'beef',
#   'individual meals',
#   'dishwashing liquid/detergent',
#   'shampoo',
#   'dishwashing liquid/detergent',
#   'dishwashing liquid/detergent',
#   'hand soap',
#   'sugar'],
#  ['ketchup',
#   'milk',
#   'poultry',
#   'cheeses',
#   'soap',
#   'toilet paper',
#   'yogurt',
#   'beef',
#   'waffles',
#   'sugar',
#   'spaghetti sauce',
#   'all- purpose',
#   'sandwich bags',
#   'toilet paper'],
#  ['laundry detergent', 'vegetables', 'shampoo', 'vegetables']]

# %% [markdown]
# ## TODO Mining association rules on Groceries datasets
# * Apply apriori and association_rules functions from mlxtend library
# * Apply apriori and association_rules functions from apriori_python library
# * What would be a reasonable value of min-support for these supermarket transaction data

# %%
# TODO: replace the content of this cell with your Python solution
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

oht = TransactionEncoder()
oht_ary = oht.fit(data_list).transform(data_list)
df = pd.DataFrame(oht_ary, columns=oht.columns_)

print(df)

frequent_itemsets = apriori(df, min_support=0.03, use_colnames=True)
print('Suport values for candidate itemsets:\n', frequent_itemsets, '\n')

rules = association_rules(frequent_itemsets, metric = 'confidence', min_threshold = 0.7)
print(rules[['antecedents','consequents','confidence']])
# Out:
#       all- purpose  aluminum foil  bagels   beef  butter  cereals  cheeses  \
# 0             True           True   False   True    True    False    False
# 1            False          False   False  False   False    False     True
# 2            False          False   False  False   False    False    False
# 3             True          False   False  False   False    False    False
# 4            False          False   False  False   False    False    False
# ...            ...            ...     ...    ...     ...      ...      ...
# 1494          True          False   False   True   False    False     True
# 1495         False          False   False  False   False     True     True
# 1496         False          False   False   True   False    False    False
# 1497          True          False   False   True   False    False     True
# 1498         False          False   False  False   False    False    False
#
#       coffee/tea  dinner rolls  dishwashing liquid/detergent  ...  shampoo  \
# 0          False          True                         False  ...     True
# 1          False         False                          True  ...     True
# 2          False          True                         False  ...    False
# 3          False         False                         False  ...    False
# 4          False         False                         False  ...    False
# ...          ...           ...                           ...  ...      ...
# 1494        True         False                         False  ...     True
# 1495       False          True                         False  ...    False
# 1496       False         False                          True  ...     True
# 1497       False         False                         False  ...    False
# 1498       False         False                         False  ...     True
#
#        soap   soda  spaghetti sauce  sugar  toilet paper  tortillas  \
# 0     False   True            False  False         False      False
# 1     False  False            False  False         False      False
# 2      True  False             True  False          True      False
# 3     False   True            False  False          True      False
# 4     False  False            False  False          True       True
# ...     ...    ...              ...    ...           ...        ...
# 1494  False  False            False  False         False      False
# 1495   True  False             True  False         False      False
# 1496  False  False            False   True         False       True
# 1497   True  False             True   True          True      False
# 1498  False  False            False  False         False      False
#
#       vegetables  waffles  yogurt
# 0           True    False   False
# 1           True     True   False
# 2          False    False   False
# 3          False    False   False
# 4           True    False   False
# ...          ...      ...     ...
# 1494       False    False   False
# 1495        True    False   False
# 1496        True    False   False
# 1497       False     True    True
# 1498        True    False   False
#
# [1499 rows x 38 columns]
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Suport values for candidate itemsets:
#         support                            itemsets
# 0     0.263509                      (all- purpose)
# 1     0.264176                     (aluminum foil)
# 2     0.278185                            (bagels)
# 3     0.262842                              (beef)
# 4     0.261508                            (butter)
# ...        ...                                 ...
# 1396  0.047365  (vegetables, toilet paper, yogurt)
# 1397  0.030020     (waffles, toilet paper, yogurt)
# 1398  0.036024    (vegetables, waffles, tortillas)
# 1399  0.045364     (vegetables, tortillas, yogurt)
# 1400  0.052035       (vegetables, waffles, yogurt)
#
# [1401 rows x 2 columns]
#
#                       antecedents   consequents  confidence
# 0    (cereals, laundry detergent)  (vegetables)    0.738739
# 1    (laundry detergent, cheeses)  (vegetables)    0.714286
# 2               (cheeses, yogurt)  (vegetables)    0.716981
# 3         (eggs, sandwich loaves)  (vegetables)    0.714286
# 4      (flour, laundry detergent)  (vegetables)    0.700935
# 5  (ice cream, laundry detergent)  (vegetables)    0.721154
# 6     (laundry detergent, yogurt)  (vegetables)    0.736842
# 7             (sugar, lunch meat)  (vegetables)    0.715517
# 8         (poultry, paper towels)  (vegetables)    0.704762

# %% [markdown]
# ## *STOP PLEASE. THE FOLLOWING IS FOR THE NEXT EXERCISE. THANKS.*

# %% [markdown]
# # EXERCISE: FP-Growth

# %% [markdown]
# ## Rules  generation using pyfpgrowth library

# %%
#Install the library if it is not available
# !pip install pyfpgrowth
import pyfpgrowth
MIN_SUPPORT = 2
MIN_CONFIDENCE = 0.7
DATASET = [['A', 'C', 'D'], ['B', 'C', 'E'], ['A', 'B', 'C','E'],['B', 'E']]

frequent_itemsets = pyfpgrowth.find_frequent_patterns(DATASET, MIN_SUPPORT)
print('Support values for candidate itemsets:\n', frequent_itemsets, '\n')
rules = pyfpgrowth.generate_association_rules(frequent_itemsets, MIN_CONFIDENCE)
print('Resultant assoication rules:\n')
pprint.pprint(rules)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Requirement already satisfied: pyfpgrowth in /usr/local/lib/python3.10/dist-packages (1.0)
# Support values for candidate itemsets:
#  {('A',): 2, ('A', 'C'): 2, ('C',): 3, ('B', 'C'): 2, ('B',): 3, ('E',): 3, ('C', 'E'): 2, ('B', 'E'): 3, ('B', 'C', 'E'): 2}
#
# Resultant assoication rules:
#
# {('A',): (('C',), 1.0),
#  ('B',): (('E',), 1.0),
#  ('B', 'C'): (('E',), 1.0),
#  ('C', 'E'): (('B',), 1.0),
#  ('E',): (('B',), 1.0)}

# %% [markdown]
# ## Rules  generation using fpgrowth_py library

# %%
# !pip install fpgrowth_py
from fpgrowth_py import fpgrowth
freqItemSet, rules = fpgrowth(DATASET, minSupRatio=0.5, minConf=0.7)
for r in rules:
    print('{} ==> {} (c={})'.format(*r))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Requirement already satisfied: fpgrowth_py in /usr/local/lib/python3.10/dist-packages (1.0.0)
# {'A'} ==> {'C'} (c=1.0)
# {'C', 'B'} ==> {'E'} (c=1.0)
# {'C', 'E'} ==> {'B'} (c=1.0)
# {'B'} ==> {'E'} (c=1.0)
# {'E'} ==> {'B'} (c=1.0)

# %% [markdown]
# ### TODO Mining association rules using FP-growth and fpgrowth_py on Groceries datasets
# * Try different confidence thresholds
# * What’s a reasonable value for real data?

# %%
MIN_SUPPORT = 0.03 * len(data_list)
MIN_CONFIDENCE = 0.8

frequent_itemsets = pyfpgrowth.find_frequent_patterns(data_list, MIN_SUPPORT)
print('Support values for candidate itemsets:\n', frequent_itemsets, '\n')
rules = pyfpgrowth.generate_association_rules(frequent_itemsets, MIN_CONFIDENCE)
print('Resultant assoication rules:\n')
pprint.pprint(rules)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Support values for candidate itemsets:
#  {('hand soap', 'hand soap'): 52, ('hand soap', 'hand soap', 'vegetables'): 45, ('hand soap', 'ketchup'): 97, ('hand soap', 'ketchup', 'vegetables'): 74, ('beef', 'hand soap', 'mixes'): 49, ('beef', 'hand soap', 'vegetables'): 81, ('hand soap', 'laundry detergent'): 100, ('hand soap', 'laundry detergent', 'vegetables'): 89, ('hand soap', 'paper towels'): 102, ('hand soap', 'paper towels', 'vegetables'): 85, ('hand soap', 'toilet paper', 'waffles'): 45, ('hand soap', 'toilet paper', 'vegetables'): 90, ('hand soap', 'toilet paper', 'vegetables', 'vegetables'): 65, ('hand soap', 'pork'): 105, ('hand soap', 'pork', 'vegetables'): 73, ('dinner rolls', 'hand soap'): 105, ('dinner rolls', 'hand soap', 'vegetables'): 89, ('cheeses', 'hand soap', 'soap'): 45, ('all- purpose', 'hand soap', 'soap'): 46, ('hand soap', 'soap', 'sugar'): 48, ('hand soap', 'soap', 'vegetables'): 66, ('hand soap', 'yogurt'): 106, ('hand soap', 'vegetables', 'yogurt'): 106, ('cereals', 'hand soap', 'spaghetti sauce'): 47, ('hand soap', 'spaghetti sauce', 'vegetables'): 69, ('hand soap', 'juice', 'mixes'): 47, ('eggs', 'hand soap', 'juice'): 49, ('hand soap', 'juice', 'vegetables'): 98, ('hand soap', 'shampoo', 'waffles'): 45, ('hand soap', 'shampoo', 'vegetables'): 94, ('aluminum foil', 'hand soap', 'waffles'): 46, ('aluminum foil', 'butter', 'hand soap'): 47, ('aluminum foil', 'hand soap', 'milk'): 48, ('aluminum foil', 'hand soap', 'vegetables'): 101, ('aluminum foil', 'hand soap', 'vegetables', 'vegetables'): 53, ('flour', 'fruits', 'hand soap'): 47, ('fruits', 'hand soap', 'waffles'): 47, ('cheeses', 'fruits', 'hand soap'): 51, ('cheeses', 'fruits', 'hand soap', 'vegetables'): 49, ('fruits', 'hand soap', 'vegetables'): 82, ('hand soap', 'mixes', 'sandwich bags'): 53, ('hand soap', 'sandwich bags', 'vegetables'): 84, ('cheeses', 'hand soap', 'sandwich loaves'): 46, ('hand soap', 'sandwich loaves', 'vegetables'): 104, ('cheeses', 'hand soap', 'individual meals'): 45, ('dishwashing liquid/detergent', 'hand soap', 'individual meals'): 47, ('cereals', 'hand soap', 'individual meals'): 49, ('cereals', 'hand soap', 'individual meals', 'vegetables'): 45, ('hand soap', 'individual meals', 'vegetables'): 112, ('hand soap', 'individual meals', 'vegetables', 'vegetables'): 69, ('hand soap', 'mixes', 'tortillas'): 50, ('hand soap', 'tortillas', 'vegetables'): 95, ('hand soap', 'tortillas', 'vegetables', 'vegetables'): 57, ('cereals', 'eggs', 'hand soap'): 47, ('eggs', 'hand soap', 'vegetables'): 114, ('eggs', 'hand soap', 'vegetables', 'vegetables'): 56, ('dishwashing liquid/detergent', 'hand soap', 'milk'): 45, ('dishwashing liquid/detergent', 'hand soap', 'mixes'): 48, ('dishwashing liquid/detergent', 'hand soap', 'lunch meat'): 48, ('dishwashing liquid/detergent', 'hand soap', 'vegetables'): 97, ('hand soap', 'mixes', 'pasta'): 46, ('hand soap', 'pasta', 'vegetables'): 106, ('hand soap', 'pasta', 'vegetables', 'vegetables'): 70, ('hand soap', 'soda', 'waffles'): 45, ('butter', 'hand soap', 'soda'): 46, ('hand soap', 'soda', 'sugar'): 51, ('hand soap', 'soda', 'sugar', 'vegetables'): 53, ('hand soap', 'soda', 'vegetables'): 114, ('hand soap', 'soda', 'vegetables', 'vegetables'): 46, ('butter', 'hand soap', 'ice cream'): 45, ('hand soap', 'ice cream', 'milk'): 46, ('hand soap', 'ice cream', 'waffles'): 47, ('hand soap', 'ice cream', 'vegetables'): 95, ('hand soap', 'ice cream', 'vegetables', 'vegetables'): 45, ('coffee/tea', 'hand soap', 'poultry'): 45, ('hand soap', 'mixes', 'poultry'): 47, ('hand soap', 'mixes', 'poultry', 'vegetables'): 51, ('hand soap', 'poultry', 'sugar'): 50, ('hand soap', 'poultry', 'sugar', 'vegetables'): 51, ('hand soap', 'poultry', 'vegetables'): 115, ('hand soap', 'poultry', 'vegetables', 'vegetables'): 66, ('coffee/tea', 'hand soap'): 126, ('coffee/tea', 'hand soap', 'vegetables'): 113, ('butter', 'hand soap', 'lunch meat'): 51, ('butter', 'hand soap', 'vegetables'): 111, ('butter', 'hand soap', 'vegetables', 'vegetables'): 48, ('all- purp ...
#
# Resultant assoication rules:
#
# {('all- purpose', 'aluminum foil'): (('vegetables',), 0.8333333333333334),
#  ('all- purpose', 'bagels', 'coffee/tea'): (('vegetables',),
#                                             0.9076923076923077),
#  ('all- purpose', 'beef', 'milk'): (('vegetables',), 0.9818181818181818),
#  ('all- purpose', 'cereals', 'paper towels'): (('vegetables',),
#                                                1.1111111111111112),
#  ('all- purpose', 'coffee/tea', 'juice'): (('vegetables',), 1.0204081632653061),
#  ('all- purpose', 'coffee/tea', 'poultry'): (('vegetables',),
#                                              1.0217391304347827),
#  ('all- purpose', 'dinner rolls', 'yogurt'): (('vegetables',), 1.0),
#  ('all- purpose', 'dishwashing liquid/detergent', 'fruits'): (('vegetables',),
#                                                               0.9056603773584906),
#  ('all- purpose', 'dishwashing liquid/detergent', 'poultry'): (('vegetables',),
#                                                                1.0444444444444445),
#  ('all- purpose', 'dishwashing liquid/detergent', 'waffles'): (('vegetables',),
#                                                                0.98),
#  ('all- purpose', 'flour', 'fruits'): (('vegetables',), 0.8490566037735849),
#  ('all- purpose', 'flour', 'waffles'): (('vegetables',), 0.8214285714285714),
#  ('all- purpose', 'fruits'): (('vegetables',), 0.8387096774193549),
#  ('all- purpose', 'fruits', 'soda'): (('vegetables',), 1.0204081632653061),
#  ('all- purpose', 'fruits', 'sugar'): (('vegetables',), 0.8181818181818182),
#  ('all- purpose', 'individual meals', 'laundry detergent'): (('vegetables',),
#                                                              0.8490566037735849),
#  ('all- purpose', 'juice', 'spaghetti sauce'): (('vegetables',),
#                                                 0.9444444444444444),
#  ('all- purpose', 'ketchup', 'yogurt'): (('vegetables',), 1.0),
#  ('all- purpose', 'milk', 'soda'): (('vegetables',), 1.0),
#  ('all- purpose', 'milk', 'waffles'): (('vegetables',), 0.9122807017543859),
#  ('all- purpose', 'milk', 'yogurt'): (('vegetables',), 1.0192307692307692),
#  ('all- purpose', 'sandwich loaves', 'waffles'): (('vegetables',),
#                                                   1.0217391304347827),
#  ('all- purpose', 'soda', 'sugar'): (('vegetables',), 0.9245283018867925),
#  ('all- purpose', 'soda', 'waffles'): (('vegetables',), 1.0192307692307692),
#  ('all- purpose', 'sugar', 'yogurt'): (('vegetables',), 1.0444444444444445),
#  ('aluminum foil', 'bagels', 'cheeses'): (('vegetables',), 1.0888888888888888),
#  ('aluminum foil', 'bagels', 'eggs'): (('vegetables',), 0.9387755102040817),
#  ('aluminum foil', 'bagels', 'laundry detergent'): (('vegetables',), 1.0),
#  ('aluminum foil', 'bagels', 'soda'): (('vegetables',), 0.9574468085106383),
#  ('aluminum foil', 'bagels', 'toilet paper'): (('vegetables',),
#                                                1.0416666666666667),
#  ('aluminum foil', 'bagels', 'waffles'): (('vegetables',), 1.3111111111111111),
#  ('aluminum foil', 'beef', 'ice cream'): (('vegetables',), 1.0350877192982457),
#  ('aluminum foil', 'beef', 'soda'): (('vegetables',), 0.9782608695652174),
#  ('aluminum foil', 'butter', 'mixes'): (('vegetables',), 1.0208333333333333),
#  ('aluminum foil', 'butter', 'poultry'): (('vegetables',), 0.9433962264150944),
#  ('aluminum foil', 'butter', 'toilet paper'): (('vegetables',),
#                                                0.9787234042553191),
#  ('aluminum foil', 'cereals', 'mixes'): (('vegetables',), 0.9180327868852459),
#  ('aluminum foil', 'cereals', 'soda'): (('vegetables',), 1.0),
#  ('aluminum foil', 'cheeses', 'dinner rolls'): (('vegetables',),
#                                                 0.9411764705882353),
#  ('aluminum foil', 'cheeses', 'flour'): (('vegetables',), 0.9622641509433962),
#  ('aluminum foil', 'cheeses', 'fruits'): (('vegetables',), 1.1333333333333333),
#  ('aluminum foil', 'cheeses', 'mixes'): (('vegetables',), 0.8793103448275862),
#  ('aluminum foil', 'cheeses', 'mixes', 'poultry'): (('vegetables',),
#                                                     1.127659574468085),
#  ('aluminum foil', 'cheeses', 'mixes', 'vegetables'): (('poultry',),
#                                                        1.0392156862745099),
#  ('aluminum foil', 'cheeses', 'poultry'): (('vegetables',), 0.8513513513513513),
#  ('aluminum foil', 'cheeses', 'poultry', 'vegetables'): (('mixes',),
#                                                          0.8412698412698413),
#  ('aluminum foil', 'cheeses', 'soda'): (('vegetables',), 1.2391304347826086),
#  ('aluminum foil', 'cheeses', 'toilet paper'): (('vegetables',),
#                                                 1.1555555555555554),
#  ('aluminum foil', 'cheeses', 'waffles'): (('vegetables',), 1.1224489795918366),
#  ('aluminum foil', 'cheeses', 'yogurt'): (('vegetables',), 1.0612244897959184),
#  ('aluminum foil', 'coffee/tea', 'dinner rolls'): (('vegetables',),
#                                                    0.9787234042553191),
#  ('aluminum foil', 'coffee/tea', 'juice'): (('vegetables',), 1.037037037037037),
#  ('aluminum foil', 'coffee/tea', 'soda'): (('vegetables',), 0.9183673469387755),
#  ('aluminum foil', 'dinner rolls'): (('vegetables',), 0.972972972972973),
#  ('aluminum foil', 'dinner rolls', 'eggs'): (('vegetables',),
#                                              0.9090909090909091),
#  ('aluminum foil', 'dinner rolls', 'paper towels'): (('vegetables',),
#                                                      1.2549019607843137),
#  ('aluminum foil', 'dishwashing liquid/detergent', 'waffles'): (('vegetables',),
#                                                                 1.1702127659574468),
#  ('aluminum foil', 'eggs', 'soda'): (('vegetables',), 0.8545454545454545),
#  ('aluminum foil', 'fruits', 'lunch meat'): (('vegetables',),
#                                              1.1111111111111112),
#  ('aluminum foil', 'ice cream', 'juice'): (('vegetables',), 1.1224489795918366),
#  ('aluminum foil', 'ice cream', 'paper towels'): (('vegetables',),
#                                                   0.9807692307692307),
#  ('aluminum foil', 'ice cream', 'poultry'): (('vegetables',),
#                                              0.9607843137254902),
#  ('aluminum foil', 'ice cream', 'soda'): (('vegetables',), 1.0769230769230769),
#  ('aluminum foil', 'ice cream', 'toilet paper'): (('vegetables',),
#                                                   0.9259259259259259),
#  ('aluminum foil', 'individual meals', 'juice'): (('vegetables',),
#                                                   0.8421052631578947),
#  ('aluminum foil', 'individual meals', 'laundry detergent'): (('vegetables',),
#                                                               0.92),
#  ('aluminum foil', 'individual meals', 'poultry'): (('vegetables',),
#                                                     0.9107142857142857),
#  ('aluminum foil', 'individual meals', 'soda'): (('vegetables',),
#                                                  1.0178571428571428),
#  ('aluminum foil', 'individual meals', 'yogurt'): (('vegetables',),
#                                                    0.9583333333333334),
#  ('aluminum foil', 'juice', 'paper towels'): (('vegetables',), 0.9),
#  ('aluminum foil', 'juice', 'soda'): (('vegetables',), 1.0434782608695652),
#  ('aluminum foil', 'laundry detergent', 'lunch meat'): (('vegetables',),
#                                                         0.9574468085106383),
#  ('aluminum foil', 'laundry detergent', 'poultry'): (('vegetables',),
#                                                      0.8490566037735849),
#  ('aluminum foil', 'laundry detergent', 'toilet paper'): (('vegetables',),
#                                                           1.108695652173913),
#  ('aluminum foil', 'lunch meat', 'pasta'): (('vegetables',),
#                                             0.9574468085106383),
#  ('aluminum foil', 'milk', 'soda'): (('vegetables',), 0.9782608695652174),
#  ('aluminum foil', 'milk', 'toilet paper'): (('vegetables',),
#                                              0.9047619047619048),
#  ('aluminum foil', 'mixes', 'pork'): (('vegetables',), 0.9787234042553191),
#  ('aluminum foil', 'mixes', 'poultry'): (('vegetables',), 1.0363636363636364),
#  ('aluminum foil', 'mixes', 'poultry', 'vegetables'): (('cheeses',),
#                                                        0.9298245614035088),
#  ('aluminum foil', 'paper towels', 'shampoo'): (('vegetables',),
#                                                 1.1111111111111112),
#  ('aluminum foil', 'paper towels', 'soda'): (('vegetables',),
#                                              1.0888888888888888),
#  ('aluminum foil', 'pasta', 'spaghetti sauce'): (('vegetables',),
#                                                  1.0222222222222221),
#  ('aluminum foil', 'poultry', 'soda'): (('vegetables',), 0.9583333333333334),
#  ('aluminum foil', 'sandwich loaves', 'shampoo'): (('vegetables',),
#                                                    0.9259259259259259),
#  ('aluminum foil', 'soda', 'sugar'): (('vegetables',), 0.9285714285714286),
#  ('aluminum foil', 'soda', 'yogurt'): (('vegetables',), 1.0980392156862746),
#  ('aluminum foil', 'waffles', 'yogurt'): (('vegetables',), 0.9574468085106383),
#  ('bagels', 'bagels'): (('vegetables',), 0.9358974358974359),
#  ('bagels', 'beef', 'milk'): (('vegetables',), 0.9298245614035088),
#  ('bagels', 'butter', 'poultry'): (('vegetables',), 1.04),
#  ('bagels', 'butter', 'spaghetti sauce'): (('vegetables',), 1.288888888888889),
#  ('bagels', 'butter', 'sugar'): (('vegetables',), 1.0888888888888888),
#  ('bagels', 'butter', 'tortillas'): (('vegetables',), 1.0178571428571428),
#  ('bagels', 'cereals', 'eggs'): (('vegetables',), 1.1111111111111112),
#  ('bagels', 'cereals', 'laundry detergent'): (('vegetables',), 1.0),
#  ('bagels', 'cereals', 'paper towels'): (('vegetables',), 0.8181818181818182),
#  ('bagels', 'cheeses', 'poultry'): (('vegetables',), 0.9215686274509803),
#  ('bagels', 'coffee/tea'): (('vegetables',), 0.8343558282208589),
#  ('bagels', 'coffee/tea', 'dishwashing liquid/detergent'): (('vegetables',),
#                                                             1.04),
#  ('bagels', 'coffee/tea', 'eggs'): (('vegetables',), 0.8275862068965517),
#  ('bagels', 'coffee/tea', 'juice'): (('vegetables',), 0.98),
#  ('bagels', 'coffee/tea', 'mixes'): (('vegetables',), 0.9193548387096774),
#  ('bagels', 'coffee/tea', 'pork'): (('vegetables',), 1.0625),
#  ('bagels', 'dishwashing liquid/detergent', 'lunch meat'): (('vegetables',),
#                                                             0.8666666666666667),
#  ('bagels', 'dishwashing liquid/detergent', 'mixes'): (('vegetables',),
#                                                        0.9818181818181818),
#  ('bagels', 'dishwashing liquid/detergent', 'poultry'): (('vegetables',),
#                                                          0.8679245283018868),
#  ('bagels', 'dishwashing liquid/detergent', 'waffles'): (('vegetables',),
#                                                          1.0576923076923077),
#  ('bagels', 'eggs', 'laundry detergent'): (('vegetables',), 0.8245614035087719),
#  ('bagels', 'eggs', 'mixes'): (('vegetables',), 1.1041666666666667),
#  ('bagels', 'eggs', 'paper towels'): (('vegetables',), 0.8888888888888888),
#  ('bagels', 'eggs', 'poultry'): (('vegetables',), 1.0638297872340425),
#  ('bagels', 'eggs', 'waffles'): (('vegetables',), 0.9787234042553191),
#  ('bagels', 'fruits', 'laundry detergent'): (('vegetables',),
#                                              0.8421052631578947),
#  ('bagels', 'fruits', 'soda'): (('vegetables',), 0.9807692307692307),
#  ('bagels', 'fruits', 'toilet paper'): (('vegetables',), 0.8490566037735849),
#  ('bagels', 'ice cream', 'pasta'): (('vegetables',), 0.8135593220338984),
#  ('bagels', 'ice cream', 'tortillas'): (('vegetables',), 0.8421052631578947),
#  ('bagels', 'laundry detergent', 'mixes'): (('vegetables',),
#                                             0.9814814814814815),
#  ('bagels', 'laundry detergent', 'toilet paper'): (('vegetables',),
#                                                    0.9019607843137255),
#  ('bagels', 'lunch meat', 'mixes'): (('vegetables',), 0.9607843137254902),
#  ('bagels', 'lunch meat', 'pasta'): (('vegetables',), 1.0),
#  ('bagels', 'lunch meat', 'tortillas'): (('vegetables',), 1.1063829787234043),
#  ('bagels', 'mixes'): (('vegetables',), 0.847457627118644),
#  ('bagels', 'mixes', 'poultry'): (('vegetables',), 1.0615384615384615),
#  ('bagels', 'mixes', 'soap'): (('vegetables',), 0.94),
#  ('bagels', 'mixes', 'soda'): (('vegetables',), 0.95),
#  ('bagels', 'mixes', 'waffles'): (('vegetables',), 1.2352941176470589),
#  ('bagels', 'pasta', 'spaghetti sauce'): (('vegetables',), 1.0740740740740742),
#  ('bagels', 'pork', 'tortillas'): (('vegetables',), 1.12),
#  ('bagels', 'pork', 'waffles'): (('vegetables',), 1.1578947368421053),
#  ('bagels', 'poultry', 'sandwich bags'): (('vegetables',), 0.8253968253968254),
#  ('bagels', 'soda'): (('vegetables',), 0.8866666666666667),
#  ('bagels', 'soda', 'spaghetti sauce'): (('vegetables',), 1.0),
#  ('bagels', 'spaghetti sauce', 'tortillas'): (('vegetables',),
#                                               1.0545454545454545),
#  ('bagels', 'spaghetti sauce', 'waffles'): (('vegetables',),
#                                             1.0754716981132075),
#  ('bagels', 'toilet paper', 'tortillas'): (('vegetables',), 1.018181818181818),
#  ('beef', 'butter'): (('vegetables',), 0.8070175438596491),
#  ('beef', 'cereals', 'individual meals'): (('vegetables',), 1.037037037037037),
#  ('beef', 'cereals', 'lunch meat'): (('vegetables',), 1.0208333333333333),
#  ('beef', 'cheeses', 'waffles'): (('vegetables',), 0.8846153846153846),
#  ('beef', 'dinner rolls', 'eggs'): (('vegetables',), 0.9215686274509803),
#  ('beef', 'dinner rolls', 'soda'): (('vegetables',), 0.8771929824561403),
#  ('beef', 'dinner rolls', 'yogurt'): (('vegetables',), 1.0),
#  ('beef', 'dishwashing liquid/detergent', 'lunch meat'): (('vegetables',),
#                                                           0.9811320754716981),
#  ('beef', 'fruits', 'ice cream'): (('vegetables',), 0.8653846153846154),
#  ('beef', 'fruits', 'ketchup'): (('vegetables',), 1.0851063829787233),
#  ('beef', 'ice cream', 'individual meals'): (('vegetables',),
#                                              0.9787234042553191),
#  ('beef', 'individual meals', 'lunch meat'): (('vegetables',),
#                                               0.9074074074074074),
#  ('beef', 'individual meals', 'poultry'): (('vegetables',), 0.9411764705882353),
#  ('beef', 'individual meals', 'yogurt'): (('vegetables',), 1.1333333333333333),
#  ('beef', 'ketchup', 'pork'): (('vegetables',), 0.9795918367346939),
#  ('beef', 'lunch meat', 'poultry'): (('vegetables',), 0.8307692307692308),
#  ('beef', 'lunch meat', 'shampoo'): (('vegetables',), 0.984375),
#  ('beef', 'poultry', 'waffles'): (('vegetables',), 1.0),
#  ('beef', 'waffles', 'yogurt'): (('vegetables',), 0.8181818181818182),
#  ('butter', 'butter'): (('vegetables',), 0.8690476190476191),
#  ('butter', 'cheeses', 'poultry'): (('vegetables',), 1.06),
#  ('butter', 'coffee/tea', 'mixes'): (('vegetables',), 1.0425531914893618),
#  ('butter', 'coffee/tea', 'sandwich loaves'): (('vegetables',),
#                                                0.9642857142857143),
#  ('butter', 'dinner rolls', 'mixes'): (('vegetables',), 0.94),
#  ('butter', 'dinner rolls', 'sandwich loaves'): (('vegetables',),
#                                                  0.9795918367346939),
#  ('butter', 'dishwashing liquid/detergent', 'poultry'): (('vegetables',), 1.0),
#  ('butter', 'eggs', 'juice'): (('vegetables',), 0.9666666666666667),
#  ('butter', 'eggs', 'poultry'): (('vegetables',), 1.2291666666666667),
#  ('butter', 'eggs', 'soda'): (('vegetables',), 0.8870967741935484),
#  ('butter', 'flour', 'mixes'): (('vegetables',), 1.173913043478261),
#  ('butter', 'fruits', 'poultry'): (('vegetables',), 1.0425531914893618),
#  ('butter', 'individual meals', 'ketchup'): (('vegetables',),
#                                              1.0434782608695652),
#  ('butter', 'juice', 'laundry detergent'): (('vegetables',),
#                                             1.0869565217391304),
#  ('butter', 'juice', 'mixes'): (('vegetables',), 1.0444444444444445),
#  ('butter', 'juice', 'sandwich loaves'): (('vegetables',), 0.9),
#  ('butter', 'juice', 'spaghetti sauce'): (('vegetables',), 1.0425531914893618),
#  ('butter', 'juice', 'toilet paper'): (('vegetables',), 0.8676470588235294),
#  ('butter', 'juice', 'waffles'): (('vegetables',), 1.0222222222222221),
#  ('butter', 'ketchup', 'lunch meat'): (('vegetables',), 1.148936170212766),
#  ('butter', 'laundry detergent', 'milk'): (('vegetables',), 0.8524590163934426),
#  ('butter', 'laundry detergent', 'poultry'): (('vegetables',), 0.9375),
#  ('butter', 'lunch meat', 'milk'): (('vegetables',), 0.8620689655172413),
#  ('butter', 'lunch meat', 'paper towels'): (('vegetables',), 0.873015873015873),
#  ('butter', 'lunch meat', 'waffles'): (('vegetables',), 0.9574468085106383),
#  ('butter', 'milk', 'mixes'): (('vegetables',), 0.9491525423728814),
#  ('butter', 'mixes', 'pork'): (('vegetables',), 1.0769230769230769),
#  ('butter', 'mixes', 'sandwich loaves'): (('vegetables',), 0.828125),
#  ('butter', 'mixes', 'spaghetti sauce'): (('vegetables',), 1.1833333333333333),
#  ('butter', 'paper towels', 'waffles'): (('vegetables',), 1.1555555555555554),
#  ('butter', 'pasta', 'spaghetti sauce'): (('vegetables',), 1.0784313725490196),
#  ('butter', 'poultry', 'soda'): (('vegetables',), 1.0),
#  ('butter', 'poultry', 'spaghetti sauce'): (('vegetables',),
#                                             1.1153846153846154),
#  ('butter', 'poultry', 'tortillas'): (('vegetables',), 1.0943396226415094),
#  ('butter', 'soap', 'spaghetti sauce'): (('vegetables',), 1.0222222222222221),
#  ('cereals', 'cereals'): (('vegetables',), 0.8048780487804879),
#  ('cereals', 'cheeses', 'soda'): (('vegetables',), 1.0434782608695652),
#  ('cereals', 'coffee/tea', 'lunch meat'): (('vegetables',), 0.9795918367346939),
#  ('cereals', 'dinner rolls', 'lunch meat'): (('vegetables',), 1.14),
#  ('cereals', 'dinner rolls', 'tortillas'): (('vegetables',),
#                                             1.0851063829787233),
#  ('cereals', 'dishwashing liquid/detergent', 'spaghetti sauce'): (('vegetables',),
#                                                                   0.8846153846153846),
#  ('cereals', 'eggs', 'paper towels'): (('vegetables',), 1.1014492753623188),
#  ('cereals', 'eggs', 'poultry'): (('vegetables',), 0.8771929824561403),
#  ('cereals', 'eggs', 'toilet paper'): (('vegetables',), 1.0740740740740742),
#  ('cereals', 'flour', 'laundry detergent'): (('vegetables',), 1.0),
#  ('cereals', 'flour', 'paper towels'): (('vegetables',), 0.9444444444444444),
#  ('cereals', 'flour', 'pasta'): (('vegetables',), 0.9649122807017544),
#  ('cereals', 'flour', 'soap'): (('vegetables',), 0.9387755102040817),
#  ('cereals', 'flour', 'spaghetti sauce'): (('vegetables',), 1.196078431372549),
#  ('cereals', 'flour', 'sugar'): (('vegetables',), 1.0638297872340425),
#  ('cereals', 'flour', 'yogurt'): (('vegetables',), 0.8727272727272727),
#  ('cereals', 'hand soap'): (('vegetables',), 0.8947368421052632),
#  ('cereals', 'hand soap', 'individual meals'): (('vegetables',),
#                                                 0.9183673469387755),
#  ('cereals', 'ice cream', 'soda'): (('vegetables',), 0.9423076923076923),
#  ('cereals', 'ice cream', 'spaghetti sauce'): (('vegetables',),
#                                                0.8363636363636363),
#  ('cereals', 'ice cream', 'sugar'): (('vegetables',), 0.9464285714285714),
#  ('cereals', 'ice cream', 'tortillas'): (('vegetables',), 1.0),
#  ('cereals', 'ice cream', 'waffles'): (('vegetables',), 1.0),
#  ('cereals', 'individual meals', 'laundry detergent'): (('vegetables',),
#                                                         1.0172413793103448),
#  ('cereals', 'juice', 'shampoo'): (('vegetables',), 0.8679245283018868),
#  ('cereals', 'laundry detergent', 'pasta'): (('vegetables',),
#                                              0.9090909090909091),
#  ('cereals', 'laundry detergent', 'sandwich bags'): (('vegetables',),
#                                                      1.0175438596491229),
#  ('cereals', 'laundry detergent', 'spaghetti sauce'): (('vegetables',),
#                                                        1.0408163265306123),
#  ('cereals', 'laundry detergent', 'sugar'): (('vegetables',), 1.0),
#  ('cereals', 'lunch meat', 'poultry'): (('vegetables',), 0.8852459016393442),
#  ('cereals', 'lunch meat', 'sugar'): (('vegetables',), 0.9166666666666666),
#  ('cereals', 'mixes', 'spaghetti sauce'): (('vegetables',), 1.0),
#  ('cereals', 'mixes', 'toilet paper'): (('vegetables',), 1.1063829787234043),
#  ('cereals', 'paper towels'): (('vegetables',), 0.8571428571428571),
#  ('cereals', 'paper towels', 'pasta'): (('vegetables',), 0.8620689655172413),
#  ('cereals', 'paper towels', 'poultry'): (('vegetables',), 0.8181818181818182),
#  ('cereals', 'paper towels', 'shampoo'): (('vegetables',), 0.9622641509433962),
#  ('cereals', 'paper towels', 'toilet paper'): (('vegetables',),
#                                                1.0588235294117647),
#  ('cereals', 'pasta', 'poultry'): (('vegetables',), 0.8846153846153846),
#  ('cereals', 'pasta', 'spaghetti sauce'): (('vegetables',), 1.14),
#  ('cereals', 'poultry'): (('vegetables',), 0.8058823529411765),
#  ('cereals', 'poultry', 'tortillas'): (('vegetables',), 0.9574468085106383),
#  ('cereals', 'soap', 'toilet paper'): (('vegetables',), 1.1875),
#  ('cereals', 'soda', 'sugar'): (('vegetables',), 0.9830508474576272),
#  ('cereals', 'soda', 'yogurt'): (('vegetables',), 0.8727272727272727),
#  ('cereals', 'spaghetti sauce'): (('vegetables',), 0.8404907975460123),
#  ('cereals', 'spaghetti sauce', 'waffles'): (('vegetables',),
#                                              0.9814814814814815),
#  ('cheeses', 'cheeses'): (('vegetables',), 1.0136986301369864),
#  ('cheeses', 'coffee/tea'): (('vegetables',), 1.0615384615384615),
#  ('cheeses', 'coffee/tea', 'pork'): (('vegetables',), 1.0363636363636364),
#  ('cheeses', 'coffee/tea', 'yogurt'): (('vegetables',), 1.3928571428571428),
#  ('cheeses', 'dinner rolls', 'eggs'): (('vegetables',), 0.9019607843137255),
#  ('cheeses', 'dinner rolls', 'flour'): (('vegetables',), 1.0212765957446808),
#  ('cheeses', 'dinner rolls', 'poultry'): (('vegetables',), 0.9016393442622951),
#  ('cheeses', 'dishwashing liquid/detergent', 'poultry'): (('vegetables',),
#                                                           1.2391304347826086),
#  ('cheeses', 'dishwashing liquid/detergent', 'toilet paper'): (('vegetables',),
#                                                                0.9782608695652174),
#  ('cheeses', 'eggs', 'flour'): (('vegetables',), 0.9591836734693877),
#  ('cheeses', 'eggs', 'poultry'): (('vegetables',), 1.0212765957446808),
#  ('cheeses', 'eggs', 'sandwich bags'): (('vegetables',), 0.8032786885245902),
#  ('cheeses', 'eggs', 'spaghetti sauce'): (('vegetables',), 1.196078431372549),
#  ('cheeses', 'eggs', 'toilet paper'): (('vegetables',), 0.9215686274509803),
#  ('cheeses', 'eggs', 'waffles'): (('vegetables',), 1.0212765957446808),
#  ('cheeses', 'flour'): (('vegetables',), 0.9565217391304348),
#  ('cheeses', 'flour', 'hand soap'): (('vegetables',), 0.9152542372881356),
#  ('cheeses', 'flour', 'laundry detergent'): (('vegetables',),
#                                              1.2173913043478262),
#  ('cheeses', 'flour', 'mixes'): (('vegetables',), 0.9574468085106383),
#  ('cheeses', 'flour', 'poultry'): (('vegetables',), 0.9019607843137255),
#  ('cheeses', 'flour', 'sandwich bags'): (('vegetables',), 0.9491525423728814),
#  ('cheeses', 'flour', 'soda'): (('vegetables',), 1.0816326530612246),
#  ('cheeses', 'flour', 'spaghetti sauce'): (('vegetables',), 1.096774193548387),
#  ('cheeses', 'flour', 'yogurt'): (('vegetables',), 0.8928571428571429),
#  ('cheeses', 'fruits', 'hand soap'): (('vegetables',), 0.9607843137254902),
#  ('cheeses', 'fruits', 'individual meals'): (('vegetables',),
#                                              1.297872340425532),
#  ('cheeses', 'fruits', 'laundry detergent'): (('vegetables',),
#                                               1.2857142857142858),
#  ('cheeses', 'fruits', 'pasta'): (('vegetables',), 0.8333333333333334),
#  ('cheeses', 'fruits', 'spaghetti sauce'): (('vegetables',),
#                                             1.0357142857142858),
#  ('cheeses', 'fruits', 'sugar'): (('vegetables',), 1.0212765957446808),
#  ('cheeses', 'fruits', 'toilet paper'): (('vegetables',), 1.1458333333333333),
#  ('cheeses', 'ketchup'): (('vegetables',), 0.9814814814814815),
#  ('cheeses', 'laundry detergent'): (('vegetables',), 1.0928571428571427),
#  ('cheeses', 'laundry detergent', 'sandwich bags'): (('vegetables',),
#                                                      1.2545454545454546),
#  ('cheeses', 'milk'): (('vegetables',), 0.9818181818181818),
#  ('cheeses', 'milk', 'yogurt'): (('vegetables',), 1.173913043478261),
#  ('cheeses', 'mixes', 'poultry', 'vegetables'): (('aluminum foil',),
#                                                  0.8833333333333333),
#  ('cheeses', 'mixes', 'yogurt'): (('vegetables',), 0.9629629629629629),
#  ('cheeses', 'pasta', 'spaghetti sauce'): (('vegetables',), 1.0754716981132075),
#  ('cheeses', 'pork', 'yogurt'): (('vegetables',), 1.0392156862745099),
#  ('cheeses', 'poultry'): (('vegetables',), 0.9141104294478528),
#  ('cheeses', 'poultry', 'toilet paper'): (('vegetables',), 0.8070175438596491),
#  ('cheeses', 'sandwich bags', 'waffles'): (('vegetables',), 0.8125),
#  ('cheeses', 'shampoo'): (('vegetables',), 0.8269230769230769),
#  ('cheeses', 'soda', 'waffles'): (('vegetables',), 0.9183673469387755),
#  ('cheeses', 'spaghetti sauce', 'sugar'): (('vegetables',), 0.8846153846153846),
#  ('cheeses', 'spaghetti sauce', 'toilet paper'): (('vegetables',),
#                                                   0.9444444444444444),
#  ('coffee/tea', 'coffee/tea'): (('vegetables',), 0.9130434782608695),
#  ('coffee/tea', 'dinner rolls', 'flour'): (('vegetables',), 1.1956521739130435),
#  ('coffee/tea', 'dinner rolls', 'lunch meat'): (('vegetables',),
#                                                 1.173913043478261),
#  ('coffee/tea', 'dinner rolls', 'tortillas'): (('vegetables',),
#                                                1.0363636363636364),
#  ('coffee/tea', 'dinner rolls', 'yogurt'): (('vegetables',),
#                                             1.0444444444444445),
#  ('coffee/tea', 'dishwashing liquid/detergent', 'mixes'): (('vegetables',),
#                                                            0.9791666666666666),
#  ('coffee/tea', 'eggs', 'pasta'): (('vegetables',), 1.0),
#  ('coffee/tea', 'flour'): (('vegetables',), 1.1120689655172413),
#  ('coffee/tea', 'hand soap'): (('vegetables',), 0.8968253968253969),
#  ('coffee/tea', 'ice cream', 'juice'): (('vegetables',), 1.0851063829787233),
#  ('coffee/tea', 'ice cream', 'poultry'): (('vegetables',), 0.8181818181818182),
#  ('coffee/tea', 'ice cream', 'soda'): (('vegetables',), 1.1346153846153846),
#  ('coffee/tea', 'ice cream', 'toilet paper'): (('vegetables',),
#                                                0.8214285714285714),
#  ('coffee/tea', 'ice cream', 'tortillas'): (('vegetables',), 0.967741935483871),
#  ('coffee/tea', 'individual meals', 'juice'): (('vegetables',),
#                                                1.1372549019607843),
#  ('coffee/tea', 'individual meals', 'mixes'): (('vegetables',),
#                                                0.9090909090909091),
#  ('coffee/tea', 'individual meals', 'pork'): (('vegetables',),
#                                               1.1886792452830188),
#  ('coffee/tea', 'individual meals', 'poultry'): (('vegetables',),
#                                                  0.8888888888888888),
#  ('coffee/tea', 'individual meals', 'toilet paper'): (('vegetables',), 0.92),
#  ('coffee/tea', 'juice', 'ketchup'): (('vegetables',), 1.0222222222222221),
#  ('coffee/tea', 'juice', 'pork'): (('vegetables',), 1.0612244897959184),
#  ('coffee/tea', 'juice', 'yogurt'): (('vegetables',), 1.2765957446808511),
#  ('coffee/tea', 'ketchup', 'pasta'): (('vegetables',), 1.1041666666666667),
#  ('coffee/tea', 'ketchup', 'pork'): (('vegetables',), 1.0188679245283019),
#  ('coffee/tea', 'ketchup', 'tortillas'): (('vegetables',), 1.0625),
#  ('coffee/tea', 'milk', 'mixes'): (('vegetables',), 0.85),
#  ('coffee/tea', 'milk', 'tortillas'): (('vegetables',), 0.8035714285714286),
#  ('coffee/tea', 'mixes', 'tortillas'): (('vegetables',), 0.94),
#  ('coffee/tea', 'paper towels', 'poultry'): (('vegetables',),
#                                              1.1372549019607843),
#  ('coffee/tea', 'pasta', 'spaghetti sauce'): (('vegetables',),
#                                               1.2666666666666666),
#  ('coffee/tea', 'pasta', 'sugar'): (('vegetables',), 0.9591836734693877),
#  ('coffee/tea', 'pasta', 'toilet paper'): (('vegetables',), 0.9230769230769231),
#  ('coffee/tea', 'pork', 'yogurt'): (('vegetables',), 1.125),
#  ('coffee/tea', 'poultry'): (('vegetables',), 0.896774193548387),
#  ('coffee/tea', 'sandwich bags'): (('vegetables',), 0.8034188034188035),
#  ('coffee/tea', 'sugar', 'tortillas'): (('vegetables',), 1.14),
#  ('coffee/tea', 'tortillas', 'yogurt'): (('vegetables',), 1.0625),
#  ('dinner rolls', 'dinner rolls'): (('vegetables',), 0.9215686274509803),
#  ('dinner rolls', 'dishwashing liquid/detergent', 'fruits'): (('vegetables',),
#                                                               1.0),
#  ('dinner rolls', 'dishwashing liquid/detergent', 'poultry'): (('vegetables',),
#                                                                1.1063829787234043),
#  ('dinner rolls', 'dishwashing liquid/detergent', 'yogurt'): (('vegetables',),
#                                                               0.9183673469387755),
#  ('dinner rolls', 'eggs', 'mixes'): (('vegetables',), 0.8947368421052632),
#  ('dinner rolls', 'eggs', 'paper towels'): (('vegetables',), 1.12),
#  ('dinner rolls', 'eggs', 'soda'): (('vegetables',), 0.9130434782608695),
#  ('dinner rolls', 'eggs', 'waffles'): (('vegetables',), 1.0204081632653061),
#  ('dinner rolls', 'hand soap'): (('vegetables',), 0.8476190476190476),
#  ('dinner rolls', 'ice cream', 'poultry'): (('vegetables',),
#                                             0.9038461538461539),
#  ('dinner rolls', 'ice cream', 'toilet paper'): (('vegetables',),
#                                                  1.0384615384615385),
#  ('dinner rolls', 'individual meals', 'poultry'): (('vegetables',), 0.94),
#  ('dinner rolls', 'juice', 'shampoo'): (('vegetables',), 1.1458333333333333),
#  ('dinner rolls', 'laundry detergent', 'paper towels'): (('vegetables',),
#                                                          0.9574468085106383),
#  ('dinner rolls', 'laundry detergent', 'shampoo'): (('vegetables',),
#                                                     0.9038461538461539),
#  ('dinner rolls', 'lunch meat', 'mixes'): (('vegetables',), 0.9444444444444444),
#  ('dinner rolls', 'lunch meat', 'poultry'): (('vegetables',),
#                                              0.9259259259259259),
#  ('dinner rolls', 'lunch meat', 'sugar'): (('vegetables',), 1.065217391304348),
#  ('dinner rolls', 'milk', 'toilet paper'): (('vegetables',),
#                                             1.1458333333333333),
#  ('dinner rolls', 'mixes', 'paper towels'): (('vegetables',),
#                                              1.065217391304348),
#  ('dinner rolls', 'mixes', 'waffles'): (('vegetables',), 0.8620689655172413),
#  ('dinner rolls', 'paper towels', 'soda'): (('vegetables',), 1.0),
#  ('dinner rolls', 'pasta', 'soda'): (('vegetables',), 0.8813559322033898),
#  ('dinner rolls', 'poultry', 'yogurt'): (('vegetables',), 0.96),
#  ('dinner rolls', 'sandwich loaves', 'waffles'): (('vegetables',),
#                                                   1.0208333333333333),
#  ('dinner rolls', 'sugar', 'yogurt'): (('vegetables',), 0.9636363636363636),
#  ('dinner rolls', 'toilet paper', 'waffles'): (('vegetables',),
#                                                0.9183673469387755),
#  ('dinner rolls', 'tortillas', 'yogurt'): (('vegetables',), 1.0),
#  ('dishwashing liquid/detergent', 'eggs', 'individual meals'): (('vegetables',),
#                                                                 0.92),
#  ('dishwashing liquid/detergent', 'eggs', 'poultry'): (('vegetables',), 1.125),
#  ('dishwashing liquid/detergent', 'eggs', 'soda'): (('vegetables',),
#                                                     1.0434782608695652),
#  ('dishwashing liquid/detergent', 'eggs', 'toilet paper'): (('vegetables',),
#                                                             0.8545454545454545),
#  ('dishwashing liquid/detergent', 'fruits', 'ice cream'): (('vegetables',),
#                                                            0.9591836734693877),
#  ('dishwashing liquid/detergent', 'fruits', 'mixes'): (('vegetables',),
#                                                        0.8095238095238095),
#  ('dishwashing liquid/detergent', 'fruits', 'poultry'): (('vegetables',), 0.9),
#  ('dishwashing liquid/detergent', 'fruits', 'sandwich bags'): (('vegetables',),
#                                                                0.9056603773584906),
#  ('dishwashing liquid/detergent', 'fruits', 'soap'): (('vegetables',), 0.9),
#  ('dishwashing liquid/detergent', 'fruits', 'soda'): (('vegetables',), 1.0),
#  ('dishwashing liquid/detergent', 'fruits', 'yogurt'): (('vegetables',),
#                                                         0.9387755102040817),
#  ('dishwashing liquid/detergent', 'ice cream', 'individual meals'): (('vegetables',),
#                                                                      0.9574468085106383),
#  ('dishwashing liquid/detergent', 'ice cream', 'lunch meat'): (('vegetables',),
#                                                                0.8490566037735849),
#  ('dishwashing liquid/detergent', 'ice cream', 'pasta'): (('vegetables',),
#                                                           0.8833333333333333),
#  ('dishwashing liquid/detergent', 'ice cream', 'poultry'): (('vegetables',),
#                                                             0.9591836734693877),
#  ('dishwashing liquid/detergent', 'ice cream', 'sugar'): (('vegetables',),
#                                                           0.9833333333333333),
#  ('dishwashing liquid/detergent', 'individual meals', 'ketchup'): (('vegetables',),
#                                                                    0.9375),
#  ('dishwashing liquid/detergent', 'individual meals', 'lunch meat'): (('vegetables',),
#                                                                       0.8771929824561403),
#  ('dishwashing liquid/detergent', 'individual meals', 'poultry'): (('vegetables',),
#                                                                    0.9841269841269841),
#  ('dishwashing liquid/detergent', 'individual meals', 'sandwich loaves'): (('vegetables',),
#                                                                            1.0),
#  ('dishwashing liquid/detergent', 'individual meals', 'sugar'): (('vegetables',),
#                                                                  1.0833333333333333),
#  ('dishwashing liquid/detergent', 'individual meals', 'toilet paper'): (('vegetables',),
#                                                                         0.8382352941176471),
#  ('dishwashing liquid/detergent', 'individual meals', 'waffles'): (('vegetables',),
#                                                                    0.9782608695652174),
#  ('dishwashing liquid/detergent', 'laundry detergent', 'lunch meat'): (('vegetables',),
#                                                                        1.0175438596491229),
#  ('dishwashing liquid/detergent', 'laundry detergent', 'toilet paper'): (('vegetables',),
#                                                                          0.9791666666666666),
#  ('dishwashing liquid/detergent', 'lunch meat', 'poultry'): (('vegetables',),
#                                                              0.9166666666666666),
#  ('dishwashing liquid/detergent', 'lunch meat', 'sugar'): (('vegetables',),
#                                                            0.9375),
#  ('dishwashing liquid/detergent', 'mixes', 'poultry'): (('vegetables',),
#                                                         0.8125),
#  ('dishwashing liquid/detergent', 'poultry'): (('vegetables',),
#                                                0.935672514619883),
#  ('dishwashing liquid/detergent', 'poultry', 'soda'): (('vegetables',),
#                                                        1.0588235294117647),
#  ('dishwashing liquid/detergent', 'poultry', 'sugar'): (('vegetables',),
#                                                         0.967741935483871),
#  ('dishwashing liquid/detergent', 'poultry', 'tortillas'): (('vegetables',),
#                                                             1.0888888888888888),
#  ('dishwashing liquid/detergent', 'poultry', 'waffles'): (('vegetables',),
#                                                           0.9387755102040817),
#  ('dishwashing liquid/detergent', 'poultry', 'yogurt'): (('vegetables',),
#                                                          0.8703703703703703),
#  ('dishwashing liquid/detergent', 'soda', 'sugar'): (('vegetables',),
#                                                      1.0666666666666667),
#  ('dishwashing liquid/detergent', 'sugar', 'waffles'): (('vegetables',),
#                                                         1.0961538461538463),
#  ('dishwashing liquid/detergent', 'sugar', 'yogurt'): (('vegetables',),
#                                                        1.169811320754717),
#  ('eggs', 'flour', 'juice'): (('vegetables',), 1.0),
#  ('eggs', 'flour', 'lunch meat'): (('vegetables',), 1.0222222222222221),
#  ('eggs', 'fruits'): (('vegetables',), 0.8333333333333334),
#  ('eggs', 'individual meals'): (('vegetables',), 0.9090909090909091),
#  ('eggs', 'juice', 'sugar'): (('vegetables',), 1.1458333333333333),
#  ('eggs', 'laundry detergent', 'sandwich bags'): (('vegetables',),
#                                                   0.9180327868852459),
#  ('eggs', 'mixes', 'paper towels'): (('vegetables',), 0.9655172413793104),
#  ('eggs', 'mixes', 'pasta'): (('vegetables',), 0.8490566037735849),
#  ('eggs', 'mixes', 'poultry'): (('vegetables',), 1.0638297872340425),
#  ('eggs', 'paper towels', 'toilet paper'): (('vegetables',),
#                                             0.8653846153846154),
#  ('eggs', 'poultry', 'soda'): (('vegetables',), 0.8771929824561403),
#  ('eggs', 'poultry', 'tortillas'): (('vegetables',), 1.1896551724137931),
#  ('eggs', 'sandwich loaves'): (('vegetables',), 0.8859649122807017),
#  ('eggs', 'soda'): (('vegetables',), 0.8390804597701149),
#  ('eggs', 'soda', 'tortillas'): (('vegetables',), 0.9444444444444444),
#  ('eggs', 'spaghetti sauce', 'waffles'): (('vegetables',), 0.9791666666666666),
#  ('eggs', 'toilet paper', 'tortillas'): (('vegetables',), 1.1568627450980393),
#  ('flour', 'flour'): (('vegetables',), 0.8714285714285714),
#  ('flour', 'fruits', 'poultry'): (('vegetables',), 1.0212765957446808),
#  ('flour', 'fruits', 'sandwich loaves'): (('vegetables',), 1.0217391304347827),
#  ('flour', 'hand soap', 'sugar'): (('vegetables',), 1.1063829787234043),
#  ('flour', 'individual meals', 'laundry detergent'): (('vegetables',),
#                                                       1.0222222222222221),
#  ('flour', 'juice', 'spaghetti sauce'): (('vegetables',), 1.1041666666666667),
#  ('flour', 'ketchup', 'laundry detergent'): (('vegetables',),
#                                              0.9074074074074074),
#  ('flour', 'laundry detergent', 'shampoo'): (('vegetables',),
#                                              0.8333333333333334),
#  ('flour', 'laundry detergent', 'soap'): (('vegetables',), 0.9795918367346939),
#  ('flour', 'laundry detergent', 'soda'): (('vegetables',), 1.5333333333333334),
#  ('flour', 'laundry detergent', 'sugar'): (('vegetables',), 0.8867924528301887),
#  ('flour', 'mixes', 'pork'): (('vegetables',), 0.9038461538461539),
#  ('flour', 'pasta', 'yogurt'): (('vegetables',), 0.8421052631578947),
#  ('flour', 'soap'): (('vegetables',), 0.80625),
#  ('flour', 'soap', 'soda'): (('vegetables',), 1.02),
#  ('flour', 'soda', 'spaghetti sauce'): (('vegetables',), 0.9090909090909091),
#  ('flour', 'spaghetti sauce', 'waffles'): (('vegetables',), 1.0),
#  ('flour', 'sugar', 'yogurt'): (('vegetables',), 0.9583333333333334),
#  ('fruits', 'fruits'): (('vegetables',), 1.0454545454545454),
#  ('fruits', 'ice cream', 'ketchup'): (('vegetables',), 1.0416666666666667),
#  ('fruits', 'ice cream', 'soda'): (('vegetables',), 0.8275862068965517),
#  ('fruits', 'ice cream', 'sugar'): (('vegetables',), 0.9),
#  ('fruits', 'individual meals', 'spaghetti sauce'): (('vegetables',), 0.890625),
#  ('fruits', 'individual meals', 'sugar'): (('vegetables',), 1.0212765957446808),
#  ('fruits', 'lunch meat', 'mixes'): (('vegetables',), 0.8518518518518519),
#  ('fruits', 'lunch meat', 'spaghetti sauce'): (('vegetables',),
#                                                0.9074074074074074),
#  ('fruits', 'pasta', 'spaghetti sauce'): (('vegetables',), 0.8870967741935484),
#  ('fruits', 'soda', 'sugar'): (('vegetables',), 1.06),
#  ('fruits', 'soda', 'waffles'): (('vegetables',), 0.8909090909090909),
#  ('hand soap', 'hand soap'): (('vegetables',), 0.8653846153846154),
#  ('hand soap', 'laundry detergent'): (('vegetables',), 0.89),
#  ('hand soap', 'lunch meat', 'waffles'): (('vegetables',), 0.9423076923076923),
#  ('hand soap', 'mixes'): (('vegetables',), 0.8947368421052632),
#  ('hand soap', 'mixes', 'poultry'): (('vegetables',), 1.0851063829787233),
#  ('hand soap', 'paper towels'): (('vegetables',), 0.8333333333333334),
#  ('hand soap', 'poultry', 'sugar'): (('vegetables',), 1.02),
#  ('hand soap', 'soda', 'sugar'): (('vegetables',), 1.0392156862745099),
#  ('hand soap', 'yogurt'): (('vegetables',), 1.0),
#  ('ice cream', 'ice cream'): (('vegetables',), 0.9240506329113924),
#  ('ice cream', 'individual meals', 'poultry'): (('vegetables',),
#                                                 0.9180327868852459),
#  ('ice cream', 'juice', 'soda'): (('vegetables',), 1.4901960784313726),
#  ('ice cream', 'juice', 'toilet paper'): (('vegetables',), 0.8571428571428571),
#  ('ice cream', 'juice', 'yogurt'): (('vegetables',), 1.1538461538461537),
#  ('ice cream', 'ketchup', 'soda'): (('vegetables',), 1.18),
#  ('ice cream', 'ketchup', 'spaghetti sauce'): (('vegetables',), 1.0),
#  ('ice cream', 'ketchup', 'yogurt'): (('vegetables',), 0.9607843137254902),
#  ('ice cream', 'laundry detergent', 'pasta'): (('vegetables',),
#                                                0.9230769230769231),
#  ('ice cream', 'laundry detergent', 'soda'): (('vegetables',),
#                                               1.1956521739130435),
#  ('ice cream', 'laundry detergent', 'sugar'): (('vegetables',),
#                                                1.0612244897959184),
#  ('ice cream', 'mixes', 'poultry'): (('vegetables',), 1.04),
#  ('ice cream', 'mixes', 'tortillas'): (('vegetables',), 0.8103448275862069),
#  ('ice cream', 'pasta', 'soda'): (('vegetables',), 0.8727272727272727),
#  ('ice cream', 'poultry'): (('vegetables',), 0.8323353293413174),
#  ('ice cream', 'sandwich bags', 'yogurt'): (('vegetables',),
#                                             0.8490566037735849),
#  ('ice cream', 'sandwich loaves', 'toilet paper'): (('vegetables',),
#                                                     1.0769230769230769),
#  ('ice cream', 'soda', 'yogurt'): (('vegetables',), 1.28),
#  ('ice cream', 'toilet paper', 'yogurt'): (('vegetables',), 1.0434782608695652),
#  ('ice cream', 'waffles'): (('vegetables',), 0.87248322147651),
#  ('individual meals', 'individual meals'): (('vegetables',), 0.8),
#  ('individual meals', 'juice', 'poultry'): (('vegetables',), 1.125),
#  ('individual meals', 'ketchup', 'sandwich loaves'): (('vegetables',),
#                                                       1.2448979591836735),
#  ('individual meals', 'lunch meat', 'poultry'): (('vegetables',),
#                                                  0.9298245614035088),
#  ('individual meals', 'lunch meat', 'sugar'): (('vegetables',),
#                                                1.0444444444444445),
#  ('individual meals', 'pork', 'poultry'): (('vegetables',), 1.0819672131147542),
#  ('individual meals', 'poultry', 'soda'): (('vegetables',), 0.9782608695652174),
#  ('individual meals', 'poultry', 'toilet paper'): (('vegetables',), 1.06),
#  ('individual meals', 'poultry', 'yogurt'): (('vegetables',),
#                                              1.0192307692307692),
#  ('individual meals', 'sandwich loaves', 'sugar'): (('vegetables',),
#                                                     1.1777777777777778),
#  ('individual meals', 'shampoo', 'toilet paper'): (('vegetables',),
#                                                    1.0851063829787233),
#  ('individual meals', 'soda', 'sugar'): (('vegetables',), 0.9193548387096774),
#  ('individual meals', 'sugar', 'yogurt'): (('vegetables',), 1.0444444444444445),
#  ('individual meals', 'waffles', 'yogurt'): (('vegetables',), 1.1875),
#  ('juice', 'ketchup', 'mixes'): (('vegetables',), 0.9846153846153847),
#  ('juice', 'laundry detergent', 'pasta'): (('vegetables',), 1.0),
#  ('juice', 'laundry detergent', 'poultry'): (('vegetables',),
#                                              0.9166666666666666),
#  ('juice', 'lunch meat', 'spaghetti sauce'): (('vegetables',),
#                                               1.1458333333333333),
#  ('juice', 'lunch meat', 'waffles'): (('vegetables',), 1.2745098039215685),
#  ('juice', 'mixes', 'spaghetti sauce'): (('vegetables',), 1.0833333333333333),
#  ('juice', 'mixes', 'yogurt'): (('vegetables',), 0.9583333333333334),
#  ('juice', 'pork', 'yogurt'): (('vegetables',), 1.0),
#  ('juice', 'poultry', 'yogurt'): (('vegetables',), 1.1346153846153846),
#  ('juice', 'sandwich bags', 'yogurt'): (('vegetables',), 1.0980392156862746),
#  ('juice', 'sandwich loaves', 'yogurt'): (('vegetables',), 0.9344262295081968),
#  ('juice', 'shampoo', 'toilet paper'): (('vegetables',), 0.9444444444444444),
#  ('juice', 'shampoo', 'yogurt'): (('vegetables',), 1.1964285714285714),
#  ('juice', 'soap', 'spaghetti sauce'): (('vegetables',), 0.9375),
#  ('juice', 'soda', 'yogurt'): (('vegetables',), 1.1454545454545455),
#  ('juice', 'spaghetti sauce', 'waffles'): (('vegetables',), 1.1639344262295082),
#  ('juice', 'sugar', 'yogurt'): (('vegetables',), 1.0),
#  ('juice', 'toilet paper'): (('vegetables',), 0.821656050955414),
#  ('juice', 'toilet paper', 'yogurt'): (('vegetables',), 1.018181818181818),
#  ('juice', 'tortillas'): (('vegetables',), 0.9174311926605505),
#  ('ketchup', 'ketchup'): (('vegetables',), 1.0377358490566038),
#  ('ketchup', 'laundry detergent', 'soap'): (('vegetables',),
#                                             0.8679245283018868),
#  ('ketchup', 'lunch meat', 'shampoo'): (('vegetables',), 0.9803921568627451),
#  ('ketchup', 'mixes'): (('vegetables',), 0.8774193548387097),
#  ('ketchup', 'mixes', 'pork'): (('vegetables',), 1.0208333333333333),
#  ('ketchup', 'mixes', 'soap'): (('vegetables',), 1.0),
#  ('ketchup', 'mixes', 'yogurt'): (('vegetables',), 1.0851063829787233),
#  ('ketchup', 'paper towels'): (('vegetables',), 0.8952380952380953),
#  ('ketchup', 'pasta', 'spaghetti sauce'): (('vegetables',), 0.94),
#  ('ketchup', 'pasta', 'sugar'): (('vegetables',), 0.9038461538461539),
#  ('ketchup', 'pork', 'poultry'): (('vegetables',), 0.9791666666666666),
#  ('ketchup', 'pork', 'soap'): (('vegetables',), 1.0),
#  ('ketchup', 'pork', 'waffles'): (('vegetables',), 0.9795918367346939),
#  ('ketchup', 'sandwich loaves', 'shampoo'): (('vegetables',),
#                                              1.0888888888888888),
#  ('ketchup', 'shampoo', 'yogurt'): (('vegetables',), 1.1914893617021276),
#  ('ketchup', 'soap', 'waffles'): (('vegetables',), 0.8135593220338984),
#  ('laundry detergent', 'laundry detergent'): (('vegetables',),
#                                               0.9538461538461539),
#  ('laundry detergent', 'lunch meat', 'milk'): (('vegetables',),
#                                                0.9411764705882353),
#  ('laundry detergent', 'lunch meat', 'pasta'): (('vegetables',),
#                                                 0.9583333333333334),
#  ('laundry detergent', 'lunch meat', 'toilet paper'): (('vegetables',), 1.0),
#  ('laundry detergent', 'lunch meat', 'tortillas'): (('vegetables',),
#                                                     1.1555555555555554),
#  ('laundry detergent', 'milk', 'sandwich bags'): (('vegetables',),
#                                                   1.0350877192982457),
#  ('laundry detergent', 'milk', 'toilet paper'): (('vegetables',),
#                                                  0.9861111111111112),
#  ('laundry detergent', 'milk', 'tortillas'): (('vegetables',), 1.0),
#  ('laundry detergent', 'milk', 'waffles'): (('vegetables',),
#                                             1.0833333333333333),
#  ('laundry detergent', 'mixes', 'poultry'): (('vegetables',),
#                                              0.9824561403508771),
#  ('laundry detergent', 'paper towels'): (('vegetables',), 0.9396551724137931),
#  ('laundry detergent', 'pasta', 'poultry'): (('vegetables',),
#                                              0.8333333333333334),
#  ('laundry detergent', 'pasta', 'spaghetti sauce'): (('vegetables',), 0.96),
#  ('laundry detergent', 'poultry'): (('vegetables',), 0.8303030303030303),
#  ('lunch meat', 'lunch meat'): (('vegetables',), 0.828125),
#  ('lunch meat', 'milk', 'waffles'): (('vegetables',), 0.9811320754716981),
#  ('lunch meat', 'mixes', 'tortillas'): (('vegetables',), 0.8653846153846154),
#  ('lunch meat', 'paper towels', 'tortillas'): (('vegetables',), 1.0),
#  ('lunch meat', 'paper towels', 'waffles'): (('vegetables',),
#                                              1.1063829787234043),
#  ('lunch meat', 'poultry'): (('vegetables',), 0.8690476190476191),
#  ('lunch meat', 'poultry', 'sugar'): (('vegetables',), 1.065217391304348),
#  ('lunch meat', 'poultry', 'yogurt'): (('vegetables',), 0.9387755102040817),
#  ('lunch meat', 'sandwich loaves', 'waffles'): (('vegetables',),
#                                                 0.8166666666666667),
#  ('lunch meat', 'soda', 'sugar'): (('vegetables',), 0.9791666666666666),
#  ('lunch meat', 'spaghetti sauce', 'waffles'): (('vegetables',),
#                                                 0.8888888888888888),
#  ('milk', 'milk'): (('vegetables',), 0.9154929577464789),
#  ('milk', 'mixes', 'toilet paper'): (('vegetables',), 1.0408163265306123),
#  ('milk', 'mixes', 'tortillas'): (('vegetables',), 0.9245283018867925),
#  ('milk', 'mixes', 'yogurt'): (('vegetables',), 0.9423076923076923),
#  ('milk', 'pasta', 'soda'): (('vegetables',), 0.8771929824561403),
#  ('milk', 'sandwich bags', 'tortillas'): (('vegetables',), 0.8823529411764706),
#  ('milk', 'soda', 'yogurt'): (('vegetables',), 0.8636363636363636),
#  ('milk', 'toilet paper', 'tortillas'): (('vegetables',), 1.0576923076923077),
#  ('milk', 'toilet paper', 'yogurt'): (('vegetables',), 1.0714285714285714),
#  ('milk', 'tortillas', 'yogurt'): (('vegetables',), 1.1304347826086956),
#  ('mixes', 'pork', 'poultry'): (('vegetables',), 0.9661016949152542),
#  ('mixes', 'poultry'): (('vegetables',), 1.01840490797546),
#  ('mixes', 'poultry', 'spaghetti sauce'): (('vegetables',), 1.1176470588235294),
#  ('mixes', 'poultry', 'sugar'): (('vegetables',), 0.9473684210526315),
#  ('mixes', 'poultry', 'yogurt'): (('vegetables',), 0.8333333333333334),
#  ('mixes', 'spaghetti sauce', 'toilet paper'): (('vegetables',),
#                                                 0.8181818181818182),
#  ('mixes', 'spaghetti sauce', 'waffles'): (('vegetables',), 0.9107142857142857),
#  ('mixes', 'toilet paper', 'tortillas'): (('vegetables',), 0.8333333333333334),
#  ('paper towels', 'pasta', 'poultry'): (('vegetables',), 0.9836065573770492),
#  ('paper towels', 'pasta', 'soap'): (('vegetables',), 1.0),
#  ('pasta', 'poultry', 'soda'): (('vegetables',), 0.9615384615384616),
#  ('pasta', 'poultry', 'spaghetti sauce'): (('vegetables',), 1.3111111111111111),
#  ('pasta', 'soda', 'spaghetti sauce'): (('vegetables',), 0.8153846153846154),
#  ('pasta', 'sugar', 'yogurt'): (('vegetables',), 0.9230769230769231),
#  ('pork', 'pork'): (('vegetables',), 0.8064516129032258),
#  ('pork', 'poultry'): (('vegetables',), 0.8859060402684564),
#  ('pork', 'poultry', 'toilet paper'): (('vegetables',), 0.9791666666666666),
#  ('pork', 'poultry', 'yogurt'): (('vegetables',), 0.9607843137254902),
#  ('pork', 'toilet paper', 'waffles'): (('vegetables',), 0.9423076923076923),
#  ('poultry', 'poultry'): (('vegetables',), 0.9125),
#  ('poultry', 'sandwich loaves', 'soap'): (('vegetables',), 1.0408163265306123),
#  ('poultry', 'soda', 'sugar'): (('vegetables',), 0.8035714285714286),
#  ('poultry', 'sugar', 'toilet paper'): (('vegetables',), 0.9607843137254902),
#  ('poultry', 'sugar', 'tortillas'): (('vegetables',), 0.8392857142857143),
#  ('poultry', 'sugar', 'waffles'): (('vegetables',), 1.0638297872340425),
#  ('poultry', 'sugar', 'yogurt'): (('vegetables',), 0.9692307692307692),
#  ('poultry', 'toilet paper', 'tortillas'): (('vegetables',),
#                                             0.9824561403508771),
#  ('poultry', 'waffles'): (('vegetables',), 0.9172932330827067),
#  ('poultry', 'waffles', 'yogurt'): (('vegetables',), 1.0208333333333333),
#  ('poultry', 'yogurt'): (('vegetables',), 0.8795180722891566),
#  ('sandwich bags', 'tortillas', 'yogurt'): (('vegetables',), 0.9),
#  ('sandwich loaves', 'shampoo', 'waffles'): (('vegetables',),
#                                              1.1555555555555554),
#  ('sandwich loaves', 'soda', 'waffles'): (('vegetables',), 1.0222222222222221),
#  ('sandwich loaves', 'toilet paper', 'waffles'): (('vegetables',), 0.953125),
#  ('shampoo', 'sugar'): (('vegetables',), 0.8344370860927153),
#  ('shampoo', 'sugar', 'yogurt'): (('vegetables',), 0.9016393442622951),
#  ('shampoo', 'tortillas'): (('vegetables',), 0.8),
#  ('soap', 'soda'): (('vegetables',), 0.8098159509202454),
#  ('soda', 'soda'): (('vegetables',), 0.9012345679012346),
#  ('soda', 'sugar'): (('vegetables',), 0.9090909090909091),
#  ('soda', 'waffles'): (('vegetables',), 0.8525641025641025),
#  ('soda', 'yogurt'): (('vegetables',), 0.95625),
#  ('spaghetti sauce', 'spaghetti sauce'): (('vegetables',), 1.0),
#  ('spaghetti sauce', 'yogurt'): (('vegetables',), 0.9552238805970149),
#  ('sugar', 'toilet paper', 'yogurt'): (('vegetables',), 1.06),
#  ('sugar', 'waffles', 'yogurt'): (('vegetables',), 1.0784313725490196),
#  ('toilet paper', 'toilet paper'): (('vegetables',), 0.9024390243902439),
#  ('toilet paper', 'waffles', 'yogurt'): (('vegetables',), 0.9682539682539683),
#  ('tortillas', 'tortillas'): (('vegetables',), 0.9692307692307692),
#  ('waffles', 'waffles'): (('vegetables',), 0.9857142857142858)}

# %% [markdown]
# # End of Tutorial. Many Thanks.

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
